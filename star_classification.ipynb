# %% [markdown]
# ### 🖥️분류 (Classification) 프로젝트 2
# #### 🌠천체 분류 예측
#
# #### ✏️feature
#
# - obj_ID: 대상의 고유 id
# - alpha: 측정 위치의 경도 (J2000 시간대 기준)
# - delta: 측정 위치의 위도(천체의 위치가 적위(celestial equator)로부터 얼마나 떨어져있는지, J2000 시간대 기준)
# - u: ultraviolet 필터에서의 광도
# - g: green 필터에서의 광도
# - r: red 필터에서의 광도
# - i: near infrared 필터에서의 광도
# - z: infrared 필터에서의 광도
# - run_ID: 특정 스캔을 식별하는 데 사용되는 실행 번호
# - rerun_ID: 이미지 처리 방법을 지정하는 재실행 번호
# - cam_col: 실행 내에서 스캔 라인을 식별하는 데 사용되는 카메라 열
# - field_ID: 각 필드를 식별하는 데 사용되는 필드 번호
# - spec_obj_ID: 광학 분광 천체를 식별하는 데 사용되는 고유 ID. 동일한 값을 가진 두 가지 다른 관측은 같은 타겟을 가져야 함.
# - redshift: 파장 증가에 기반한 레드시프트 값. 천체의 속도와 거리를 나타냄.
# - plate: SDSS에서 각 plate를 식별하는 plate ID
# - MJD: 수정 율리우스력에 기반한 날짜로, 주어진 SDSS 데이터가 촬영된 날짜
# - fiber_ID: 각 관측에서 광을 초점면에 지시하는 광섬유를 식별하는 광섬유 ID
#
# #### 🎈target
#
# - class: 천체의 종류 (GALAXY(은하), STAR(별), QSO(퀘이사))

# %% [markdown]
# ### 목차
#
# 1. 데이터 탐색 및 분포 시각화
# 2. 데이터 전처리 및 훈련/학습 데이터 분리
# 3. 모델 훈련, 예측 및 평가
#    - DTC
#    - SVC
#    - KNN
#    - Ensemble(Hard/soft Voting[DTC, SVC, KNN], Bagging[RFC], Boosting[AdaBoost, GBM, XGB, LightGBM])
# 4. 정확도 및 F1 score 비교 분석

# %% [markdown]
# #### 1. 데이터 탐색 및 분포 시각화
#
# - 중복행, 결측치 검사
# - 분포 시각화, 상관관계 확인 및 이상치 검사

# %% [markdown]
# - 데이터를 읽어옵니다.

# %%
import pandas as pd

s_df = pd.read_csv('./datasets/star_dataset.csv', low_memory=False)
s_df
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 0      1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1      1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2      1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3      1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4      1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
# ...             ...         ...        ...       ...       ...       ...
# 99995  1.237679e+18   39.620709  -2.594074  22.16759  22.97586  21.90404
# 99996  1.237679e+18   29.493819  19.798874  22.69118  22.38628  20.45003
# 99997  1.237668e+18  224.587407  15.700707  21.16916  19.26997  18.20428
# 99998  1.237661e+18  212.268621  46.660365  25.35039  21.63757  19.91386
# 99999  1.237661e+18  196.896053  49.464643  22.62171  21.79745  20.60115
#
#               i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 0      19.16573  18.79371    3606       301        2        79  6.543777e+18
# 1      21.16812  21.61427    4518       301        5       119  1.176014e+19
# 2      19.34857  18.94827    3606       301        2       120  5.152200e+18
# 3      20.50454  19.25010    4192       301        3       214  1.030107e+19
# 4      15.97711  15.54461    8102       301        3       137  6.891865e+18
# ...         ...       ...     ...       ...      ...       ...           ...
# 99995  21.30548  20.73569    7778       301        2       581  1.055431e+19
# 99996  19.75759  19.41526    7917       301        1       289  8.586351e+18
# 99997  17.69034  17.35221    5314       301        4       308  3.112008e+18
# 99998  19.07254  18.62482    3650       301        4       131  7.601080e+18
# 99999  20.00959  19.28075    3650       301        4        60  8.343152e+18
#
#         class  redshift  plate    MJD  fiber_ID
# 0      GALAXY  0.634794   5812  56354       171
# 1      GALAXY  0.779136  10445  58158       427
# 2      GALAXY  0.644195   4576  55592       299
# 3      GALAXY  0.932346   9149  58039       775
# 4      GALAXY  0.116123   6121  56187       842
# ...       ...       ...    ...    ...       ...
# 99995  GALAXY  0.000000   9374  57749       438
# 99996  GALAXY  0.404895   7626  56934       866
# 99997  GALAXY  0.143366   2764  54535        74
# 99998  GALAXY  0.455040   6751  56368       470
# 99999  GALAXY  0.542944   7410  57104       851
#
# [100000 rows x 18 columns]

# %% [markdown]
# - 데이터의 정보를 확인해봅니다.

# %%
s_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   obj_ID       100000 non-null  float64
#  1   alpha        100000 non-null  float64
#  2   delta        100000 non-null  float64
#  3   u            100000 non-null  float64
#  4   g            100000 non-null  float64
#  5   r            100000 non-null  float64
#  6   i            100000 non-null  float64
#  7   z            100000 non-null  float64
#  8   run_ID       100000 non-null  int64
#  9   rerun_ID     100000 non-null  int64
#  10  cam_col      100000 non-null  int64
#  11  field_ID     100000 non-null  int64
#  12  spec_obj_ID  100000 non-null  float64
#  13  class        100000 non-null  object
#  14  redshift     100000 non-null  float64
#  15  plate        100000 non-null  int64
#  16  MJD          100000 non-null  int64
#  17  fiber_ID     100000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# memory usage: 13.7+ MB

# %% [markdown]
# - 중복행을 검사합니다.

# %%
s_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - 결측치를 검사합니다.

# %%
s_df.isna().sum()
# Out:
# obj_ID         0
# alpha          0
# delta          0
# u              0
# g              0
# r              0
# i              0
# z              0
# run_ID         0
# rerun_ID       0
# cam_col        0
# field_ID       0
# spec_obj_ID    0
# class          0
# redshift       0
# plate          0
# MJD            0
# fiber_ID       0
# dtype: int64

# %% [markdown]
# - 히스토그램을 통해 각 feature별 분포를 확인해봅니다.

# %%
s_df.hist(figsize=(15, 15))
# Out:
# array([[<Axes: title={'center': 'obj_ID'}>,
#         <Axes: title={'center': 'alpha'}>,
#         <Axes: title={'center': 'delta'}>, <Axes: title={'center': 'u'}>],
#        [<Axes: title={'center': 'g'}>, <Axes: title={'center': 'r'}>,
#         <Axes: title={'center': 'i'}>, <Axes: title={'center': 'z'}>],
#        [<Axes: title={'center': 'run_ID'}>,
#         <Axes: title={'center': 'rerun_ID'}>,
#         <Axes: title={'center': 'cam_col'}>,
#         <Axes: title={'center': 'field_ID'}>],
#        [<Axes: title={'center': 'spec_obj_ID'}>,
#         <Axes: title={'center': 'redshift'}>,
#         <Axes: title={'center': 'plate'}>,
#         <Axes: title={'center': 'MJD'}>],
#        [<Axes: title={'center': 'fiber_ID'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %% [markdown]
# - 수치형 데이터에 대해 상관관계를 확인해봅니다.

# %%
corr_s_df = s_df.drop(labels=['class'], axis=1)
corr = corr_s_df.corr()
corr
# Out:
#                obj_ID     alpha     delta         u         g         r  \
# obj_ID       1.000000 -0.013735 -0.301237  0.015310  0.015710  0.153891
# alpha       -0.013735  1.000000  0.138691 -0.001532 -0.002423 -0.022083
# delta       -0.301237  0.138691  1.000000  0.002074  0.003523 -0.006835
# u            0.015310 -0.001532  0.002074  1.000000  0.999311  0.054149
# g            0.015710 -0.002423  0.003523  0.999311  1.000000  0.062387
# r            0.153891 -0.022083 -0.006835  0.054149  0.062387  1.000000
# i            0.147670 -0.023580 -0.004480  0.045730  0.056271  0.962868
# z            0.013811 -0.002918  0.003630  0.998093  0.999161  0.053677
# run_ID       1.000000 -0.013737 -0.301238  0.015309  0.015710  0.153889
# rerun_ID          NaN       NaN       NaN       NaN       NaN       NaN
# cam_col     -0.046997  0.019582  0.032565  0.003548  0.003508  0.008480
# field_ID     0.031498 -0.165577 -0.173416 -0.008374 -0.008852 -0.026423
# spec_obj_ID  0.239461 -0.002553  0.112329  0.029997  0.039443  0.655245
# redshift     0.065400  0.001667  0.031638  0.014309  0.022954  0.433241
# plate        0.239460 -0.002554  0.112329  0.029997  0.039443  0.655243
# MJD          0.262687  0.019943  0.107333  0.031997  0.040274  0.671180
# fiber_ID     0.067178  0.030464  0.028250  0.016305  0.017470  0.223106
#
#                     i         z    run_ID  rerun_ID   cam_col  field_ID  \
# obj_ID       0.147670  0.013811  1.000000       NaN -0.046997  0.031498
# alpha       -0.023580 -0.002918 -0.013737       NaN  0.019582 -0.165577
# delta       -0.004480  0.003630 -0.301238       NaN  0.032565 -0.173416
# u            0.045730  0.998093  0.015309       NaN  0.003548 -0.008374
# g            0.056271  0.999161  0.015710       NaN  0.003508 -0.008852
# r            0.962868  0.053677  0.153889       NaN  0.008480 -0.026423
# i            1.000000  0.055994  0.147668       NaN  0.007615 -0.026679
# z            0.055994  1.000000  0.013811       NaN  0.003365 -0.008903
# run_ID       0.147668  0.013811  1.000000       NaN -0.047098  0.031498
# rerun_ID          NaN       NaN       NaN       NaN       NaN       NaN
# cam_col      0.007615  0.003365 -0.047098       NaN  1.000000 -0.015684
# field_ID    -0.026679 -0.008903  0.031498       NaN -0.015684  1.000000
# spec_obj_ID  0.661641  0.037813  0.239460       NaN -0.001946 -0.083471
# redshift     0.492383  0.030380  0.065400       NaN  0.000097 -0.021331
# plate        0.661640  0.037813  0.239459       NaN -0.001949 -0.083471
# MJD          0.672523  0.037469  0.262687       NaN -0.006745 -0.095064
# fiber_ID     0.214787  0.014668  0.067165       NaN  0.121597 -0.012337
#
#              spec_obj_ID  redshift     plate       MJD  fiber_ID
# obj_ID          0.239461  0.065400  0.239460  0.262687  0.067178
# alpha          -0.002553  0.001667 -0.002554  0.019943  0.030464
# delta           0.112329  0.031638  0.112329  0.107333  0.028250
# u               0.029997  0.014309  0.029997  0.031997  0.016305
# g               0.039443  0.022954  0.039443  0.040274  0.017470
# r               0.655245  0.433241  0.655243  0.671180  0.223106
# i               0.661641  0.492383  0.661640  0.672523  0.214787
# z               0.037813  0.030380  0.037813  0.037469  0.014668
# run_ID          0.239460  0.065400  0.239459  0.262687  0.067165
# rerun_ID             NaN       NaN       NaN       NaN       NaN
# cam_col        -0.001946  0.000097 -0.001949 -0.006745  0.121597
# field_ID       -0.083471 -0.021331 -0.083471 -0.095064 -0.012337
# spec_obj_ID     1.000000  0.388642  1.000000  0.970167  0.241279
# redshift        0.388642  1.000000  0.388641  0.387109  0.127044
# plate           1.000000  0.388641  1.000000  0.970166  0.241258
# MJD             0.970167  0.387109  0.970166  1.000000  0.256970
# fiber_ID        0.241279  0.127044  0.241258  0.256970  1.000000

# %% [markdown]
# - rerun_ID의 분포를 확인해봅니다.

# %%
s_df['rerun_ID'].value_counts()
# Out:
# rerun_ID
# 301    100000
# Name: count, dtype: int64

# %% [markdown]
# - 📌모두 같은 값을 가지므로 훈련 시 해당 feature를 제거하고 진행하기로 합니다.

# %%
s_df = s_df.drop(labels=['rerun_ID'], axis=1)
s_df
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 0      1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1      1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2      1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3      1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4      1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
# ...             ...         ...        ...       ...       ...       ...
# 99995  1.237679e+18   39.620709  -2.594074  22.16759  22.97586  21.90404
# 99996  1.237679e+18   29.493819  19.798874  22.69118  22.38628  20.45003
# 99997  1.237668e+18  224.587407  15.700707  21.16916  19.26997  18.20428
# 99998  1.237661e+18  212.268621  46.660365  25.35039  21.63757  19.91386
# 99999  1.237661e+18  196.896053  49.464643  22.62171  21.79745  20.60115
#
#               i         z  run_ID  cam_col  field_ID   spec_obj_ID   class  \
# 0      19.16573  18.79371    3606        2        79  6.543777e+18  GALAXY
# 1      21.16812  21.61427    4518        5       119  1.176014e+19  GALAXY
# 2      19.34857  18.94827    3606        2       120  5.152200e+18  GALAXY
# 3      20.50454  19.25010    4192        3       214  1.030107e+19  GALAXY
# 4      15.97711  15.54461    8102        3       137  6.891865e+18  GALAXY
# ...         ...       ...     ...      ...       ...           ...     ...
# 99995  21.30548  20.73569    7778        2       581  1.055431e+19  GALAXY
# 99996  19.75759  19.41526    7917        1       289  8.586351e+18  GALAXY
# 99997  17.69034  17.35221    5314        4       308  3.112008e+18  GALAXY
# 99998  19.07254  18.62482    3650        4       131  7.601080e+18  GALAXY
# 99999  20.00959  19.28075    3650        4        60  8.343152e+18  GALAXY
#
#        redshift  plate    MJD  fiber_ID
# 0      0.634794   5812  56354       171
# 1      0.779136  10445  58158       427
# 2      0.644195   4576  55592       299
# 3      0.932346   9149  58039       775
# 4      0.116123   6121  56187       842
# ...         ...    ...    ...       ...
# 99995  0.000000   9374  57749       438
# 99996  0.404895   7626  56934       866
# 99997  0.143366   2764  54535        74
# 99998  0.455040   6751  56368       470
# 99999  0.542944   7410  57104       851
#
# [100000 rows x 17 columns]

# %% [markdown]
# - target(종속 변수)을 제외한 feature(독립 변수)에 대해 상관관계를 시각화해봅니다.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

feature_s_df = s_df.drop(labels=['class'], axis=1)
feature_corr = feature_s_df.corr()

fig = plt.figure(figsize=(10, 7))
heatmap = sns.heatmap(feature_corr, cmap='Oranges')
heatmap.set_title('Correlation')
plt.show()

# %% [markdown]
# - target('class')와의 상관관계를 확인해보기 위해, 레이블 인코딩을 진행합니다.

# %%
from sklearn.preprocessing import LabelEncoder

target_encoder = LabelEncoder()
targets = target_encoder.fit_transform(s_df['class'])
s_df['target'] = targets
s_df.drop(labels=['class'], axis=1, inplace=True)
s_df
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 0      1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1      1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2      1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3      1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4      1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
# ...             ...         ...        ...       ...       ...       ...
# 99995  1.237679e+18   39.620709  -2.594074  22.16759  22.97586  21.90404
# 99996  1.237679e+18   29.493819  19.798874  22.69118  22.38628  20.45003
# 99997  1.237668e+18  224.587407  15.700707  21.16916  19.26997  18.20428
# 99998  1.237661e+18  212.268621  46.660365  25.35039  21.63757  19.91386
# 99999  1.237661e+18  196.896053  49.464643  22.62171  21.79745  20.60115
#
#               i         z  run_ID  cam_col  field_ID   spec_obj_ID  redshift  \
# 0      19.16573  18.79371    3606        2        79  6.543777e+18  0.634794
# 1      21.16812  21.61427    4518        5       119  1.176014e+19  0.779136
# 2      19.34857  18.94827    3606        2       120  5.152200e+18  0.644195
# 3      20.50454  19.25010    4192        3       214  1.030107e+19  0.932346
# 4      15.97711  15.54461    8102        3       137  6.891865e+18  0.116123
# ...         ...       ...     ...      ...       ...           ...       ...
# 99995  21.30548  20.73569    7778        2       581  1.055431e+19  0.000000
# 99996  19.75759  19.41526    7917        1       289  8.586351e+18  0.404895
# 99997  17.69034  17.35221    5314        4       308  3.112008e+18  0.143366
# 99998  19.07254  18.62482    3650        4       131  7.601080e+18  0.455040
# 99999  20.00959  19.28075    3650        4        60  8.343152e+18  0.542944
#
#        plate    MJD  fiber_ID  target
# 0       5812  56354       171       0
# 1      10445  58158       427       0
# 2       4576  55592       299       0
# 3       9149  58039       775       0
# 4       6121  56187       842       0
# ...      ...    ...       ...     ...
# 99995   9374  57749       438       0
# 99996   7626  56934       866       0
# 99997   2764  54535        74       0
# 99998   6751  56368       470       0
# 99999   7410  57104       851       0
#
# [100000 rows x 17 columns]

# %%
corr = s_df.corr()
corr
# Out:
#                obj_ID     alpha     delta         u         g         r  \
# obj_ID       1.000000 -0.013735 -0.301237  0.015310  0.015710  0.153891
# alpha       -0.013735  1.000000  0.138691 -0.001532 -0.002423 -0.022083
# delta       -0.301237  0.138691  1.000000  0.002074  0.003523 -0.006835
# u            0.015310 -0.001532  0.002074  1.000000  0.999311  0.054149
# g            0.015710 -0.002423  0.003523  0.999311  1.000000  0.062387
# r            0.153891 -0.022083 -0.006835  0.054149  0.062387  1.000000
# i            0.147670 -0.023580 -0.004480  0.045730  0.056271  0.962868
# z            0.013811 -0.002918  0.003630  0.998093  0.999161  0.053677
# run_ID       1.000000 -0.013737 -0.301238  0.015309  0.015710  0.153889
# cam_col     -0.046997  0.019582  0.032565  0.003548  0.003508  0.008480
# field_ID     0.031498 -0.165577 -0.173416 -0.008374 -0.008852 -0.026423
# spec_obj_ID  0.239461 -0.002553  0.112329  0.029997  0.039443  0.655245
# redshift     0.065400  0.001667  0.031638  0.014309  0.022954  0.433241
# plate        0.239460 -0.002554  0.112329  0.029997  0.039443  0.655243
# MJD          0.262687  0.019943  0.107333  0.031997  0.040274  0.671180
# fiber_ID     0.067178  0.030464  0.028250  0.016305  0.017470  0.223106
# target      -0.036012 -0.011756  0.014452 -0.024645 -0.020066 -0.076766
#
#                     i         z    run_ID   cam_col  field_ID  spec_obj_ID  \
# obj_ID       0.147670  0.013811  1.000000 -0.046997  0.031498     0.239461
# alpha       -0.023580 -0.002918 -0.013737  0.019582 -0.165577    -0.002553
# delta       -0.004480  0.003630 -0.301238  0.032565 -0.173416     0.112329
# u            0.045730  0.998093  0.015309  0.003548 -0.008374     0.029997
# g            0.056271  0.999161  0.015710  0.003508 -0.008852     0.039443
# r            0.962868  0.053677  0.153889  0.008480 -0.026423     0.655245
# i            1.000000  0.055994  0.147668  0.007615 -0.026679     0.661641
# z            0.055994  1.000000  0.013811  0.003365 -0.008903     0.037813
# run_ID       0.147668  0.013811  1.000000 -0.047098  0.031498     0.239460
# cam_col      0.007615  0.003365 -0.047098  1.000000 -0.015684    -0.001946
# field_ID    -0.026679 -0.008903  0.031498 -0.015684  1.000000    -0.083471
# spec_obj_ID  0.661641  0.037813  0.239460 -0.001946 -0.083471     1.000000
# redshift     0.492383  0.030380  0.065400  0.000097 -0.021331     0.388642
# plate        0.661640  0.037813  0.239459 -0.001949 -0.083471     1.000000
# MJD          0.672523  0.037469  0.262687 -0.006745 -0.095064     0.970167
# fiber_ID     0.214787  0.014668  0.067165  0.121597 -0.012337     0.241279
# target       0.015028 -0.001614 -0.036014  0.023138 -0.034833    -0.010060
#
#              redshift     plate       MJD  fiber_ID    target
# obj_ID       0.065400  0.239460  0.262687  0.067178 -0.036012
# alpha        0.001667 -0.002554  0.019943  0.030464 -0.011756
# delta        0.031638  0.112329  0.107333  0.028250  0.014452
# u            0.014309  0.029997  0.031997  0.016305 -0.024645
# g            0.022954  0.039443  0.040274  0.017470 -0.020066
# r            0.433241  0.655243  0.671180  0.223106 -0.076766
# i            0.492383  0.661640  0.672523  0.214787  0.015028
# z            0.030380  0.037813  0.037469  0.014668 -0.001614
# run_ID       0.065400  0.239459  0.262687  0.067165 -0.036014
# cam_col      0.000097 -0.001949 -0.006745  0.121597  0.023138
# field_ID    -0.021331 -0.083471 -0.095064 -0.012337 -0.034833
# spec_obj_ID  0.388642  1.000000  0.970167  0.241279 -0.010060
# redshift     1.000000  0.388641  0.387109  0.127044 -0.054239
# plate        0.388641  1.000000  0.970166  0.241258 -0.010060
# MJD          0.387109  0.970166  1.000000  0.256970 -0.000405
# fiber_ID     0.127044  0.241258  0.256970  1.000000 -0.041586
# target      -0.054239 -0.010060 -0.000405 -0.041586  1.000000

# %% [markdown]
# - target과의 상관관계를 확인해봅니다.

# %%
corr['target'].sort_values(ascending=False)[1:]
# Out:
# cam_col        0.023138
# i              0.015028
# delta          0.014452
# MJD           -0.000405
# z             -0.001614
# plate         -0.010060
# spec_obj_ID   -0.010060
# alpha         -0.011756
# g             -0.020066
# u             -0.024645
# field_ID      -0.034833
# obj_ID        -0.036012
# run_ID        -0.036014
# fiber_ID      -0.041586
# redshift      -0.054239
# r             -0.076766
# Name: target, dtype: float64

# %% [markdown]
# - 📌target과의 상관관계가 대체로 매우 낮게 나타나지만, 우선 훈련 및 예측까지 수행하여 평가 지표를 확인해보고자 합니다.

# %%
s_df
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 0      1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1      1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2      1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3      1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4      1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
# ...             ...         ...        ...       ...       ...       ...
# 99995  1.237679e+18   39.620709  -2.594074  22.16759  22.97586  21.90404
# 99996  1.237679e+18   29.493819  19.798874  22.69118  22.38628  20.45003
# 99997  1.237668e+18  224.587407  15.700707  21.16916  19.26997  18.20428
# 99998  1.237661e+18  212.268621  46.660365  25.35039  21.63757  19.91386
# 99999  1.237661e+18  196.896053  49.464643  22.62171  21.79745  20.60115
#
#               i         z  run_ID  cam_col  field_ID   spec_obj_ID  redshift  \
# 0      19.16573  18.79371    3606        2        79  6.543777e+18  0.634794
# 1      21.16812  21.61427    4518        5       119  1.176014e+19  0.779136
# 2      19.34857  18.94827    3606        2       120  5.152200e+18  0.644195
# 3      20.50454  19.25010    4192        3       214  1.030107e+19  0.932346
# 4      15.97711  15.54461    8102        3       137  6.891865e+18  0.116123
# ...         ...       ...     ...      ...       ...           ...       ...
# 99995  21.30548  20.73569    7778        2       581  1.055431e+19  0.000000
# 99996  19.75759  19.41526    7917        1       289  8.586351e+18  0.404895
# 99997  17.69034  17.35221    5314        4       308  3.112008e+18  0.143366
# 99998  19.07254  18.62482    3650        4       131  7.601080e+18  0.455040
# 99999  20.00959  19.28075    3650        4        60  8.343152e+18  0.542944
#
#        plate    MJD  fiber_ID  target
# 0       5812  56354       171       0
# 1      10445  58158       427       0
# 2       4576  55592       299       0
# 3       9149  58039       775       0
# 4       6121  56187       842       0
# ...      ...    ...       ...     ...
# 99995   9374  57749       438       0
# 99996   7626  56934       866       0
# 99997   2764  54535        74       0
# 99998   6751  56368       470       0
# 99999   7410  57104       851       0
#
# [100000 rows x 17 columns]

# %% [markdown]
# #### 2. 데이터 전처리 및 훈련/학습 데이터 분리
# - 히스토그램으로 보았을 때 분포가 치우쳐 나타난 u, g, z feature들의 분포를 value_counts()로 확인해봅니다.
# - train_test_split()을 통해 훈련 및 학습 데이터를 분리합니다.
# - 훈련 데이터에서 target의 분포를 확인하여 필요 시 undersampling 또는 oversampling을 진행합니다.

# %%
pre_s_df = s_df.copy()
pre_s_df
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 0      1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1      1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2      1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3      1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4      1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
# ...             ...         ...        ...       ...       ...       ...
# 99995  1.237679e+18   39.620709  -2.594074  22.16759  22.97586  21.90404
# 99996  1.237679e+18   29.493819  19.798874  22.69118  22.38628  20.45003
# 99997  1.237668e+18  224.587407  15.700707  21.16916  19.26997  18.20428
# 99998  1.237661e+18  212.268621  46.660365  25.35039  21.63757  19.91386
# 99999  1.237661e+18  196.896053  49.464643  22.62171  21.79745  20.60115
#
#               i         z  run_ID  cam_col  field_ID   spec_obj_ID  redshift  \
# 0      19.16573  18.79371    3606        2        79  6.543777e+18  0.634794
# 1      21.16812  21.61427    4518        5       119  1.176014e+19  0.779136
# 2      19.34857  18.94827    3606        2       120  5.152200e+18  0.644195
# 3      20.50454  19.25010    4192        3       214  1.030107e+19  0.932346
# 4      15.97711  15.54461    8102        3       137  6.891865e+18  0.116123
# ...         ...       ...     ...      ...       ...           ...       ...
# 99995  21.30548  20.73569    7778        2       581  1.055431e+19  0.000000
# 99996  19.75759  19.41526    7917        1       289  8.586351e+18  0.404895
# 99997  17.69034  17.35221    5314        4       308  3.112008e+18  0.143366
# 99998  19.07254  18.62482    3650        4       131  7.601080e+18  0.455040
# 99999  20.00959  19.28075    3650        4        60  8.343152e+18  0.542944
#
#        plate    MJD  fiber_ID  target
# 0       5812  56354       171       0
# 1      10445  58158       427       0
# 2       4576  55592       299       0
# 3       9149  58039       775       0
# 4       6121  56187       842       0
# ...      ...    ...       ...     ...
# 99995   9374  57749       438       0
# 99996   7626  56934       866       0
# 99997   2764  54535        74       0
# 99998   6751  56368       470       0
# 99999   7410  57104       851       0
#
# [100000 rows x 17 columns]

# %%
pre_s_df['u'].value_counts()
# Out:
# u
# 24.63465    77
# 24.63466    64
# 24.63467    44
# 24.63464    23
# 24.63468    20
#             ..
# 20.52900     1
# 20.71782     1
# 24.04446     1
# 26.04562     1
# 22.62171     1
# Name: count, Length: 93748, dtype: int64

# %%
pre_s_df['u'].hist()
# Out:
# <Axes: >

# %%
pre_s_df[['u']].describe().T
# Out:
#       count       mean        std     min        25%        50%       75%  \
# u  100000.0  21.980468  31.769291 -9999.0  20.352353  22.179135  23.68744
#
#         max
# u  32.78139

# %% [markdown]
# - 📌'u' feature에서 최솟값이 -9999로, 평균값이나 최댓값, 4분위값을 기준으로 했을 때 이상치로 판단됩니다.

# %%
pre_s_df[['g']].describe().T
# Out:
#       count       mean        std     min       25%        50%        75%  \
# g  100000.0  20.531387  31.750292 -9999.0  18.96523  21.099835  22.123767
#
#         max
# g  31.60224

# %% [markdown]
# - 📌'g' feature 또한 최솟값이 -9999로, 평균값이나 최댓값, 4분위값을 기준으로 했을 때 이상치로 판단됩니다.

# %%
pre_s_df[['z']].describe().T
# Out:
#       count      mean        std     min        25%        50%       75%  \
# z  100000.0  18.66881  31.728152 -9999.0  17.460677  19.004595  19.92112
#
#         max
# z  29.38374

# %% [markdown]
# - 📌'z' feature 또한 최솟값이 -9999로, 평균값이나 최댓값, 4분위값을 기준으로 했을 때 이상치로 판단됩니다.

# %% [markdown]
# - 🎈히스토그램으로 보았을 때 u, g, z feature는 하나의 값만을 가진 것으로 판단하여 컬럼을 삭제하려 하였으나,
#   describe().T로 확인해보았을 때 이상치로 인하여 치우친 분포를 나타냈던 것을 알 수 있습니다.
# - 따라서 전체 feature에 대해 StandardScaler()를 통해 표준화를 진행한 후 이상치를 제거하고자 합니다.

# %%
from sklearn.preprocessing import StandardScaler

features = pre_s_df.iloc[:, :-1]

std = StandardScaler()
std_features = std.fit_transform(features)
std_s_df = pd.DataFrame(std_features, columns=features.columns)
std_s_df['target'] = pre_s_df['target']
std_s_df
# Out:
#          obj_ID     alpha     delta         u         g         r         i  \
# 0     -0.445634 -0.434604  0.425529  0.059755  0.054926  0.403962  0.046007
# 1      0.018740 -0.339921  0.363402  0.088045  0.072456  1.584406  1.185097
# 2     -0.445633 -0.367251  0.582713  0.103327  0.067165  0.519745  0.150019
# 3     -0.147311  1.669523 -1.249105  0.004921  0.102210  1.059904  0.807610
# 4      1.842768  1.737310 -0.150242 -0.080055 -0.092948 -1.697421 -1.767887
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995  1.677801 -1.430113 -1.360650  0.005890  0.076991  1.217564  1.263237
# 99996  1.748482 -1.535053 -0.220744  0.022371  0.058422  0.433626  0.382696
# 99997  0.423819  0.486606 -0.429360 -0.025538 -0.039730 -0.777184 -0.793290
# 99998 -0.423111  0.358952  1.146631  0.106075  0.034840  0.144547 -0.007005
# 99999 -0.423112  0.199654  1.289381  0.020184  0.039876  0.515103  0.526050
#
#               z    run_ID   cam_col  field_ID  spec_obj_ID  redshift  \
# 0      0.003937 -0.445535 -0.952553 -0.718947     0.228609  0.079557
# 1      0.092835  0.018646  0.937920 -0.450509     1.797912  0.277096
# 2      0.008808 -0.445535 -0.952553 -0.443798    -0.190037  0.092423
# 3      0.018321 -0.147278 -0.322395  0.187031     1.358962  0.486770
# 4     -0.098468  1.842792 -0.322395 -0.329712     0.333328 -0.630267
# ...         ...       ...       ...       ...          ...       ...
# 99995  0.065144  1.677886 -0.952553  2.649947     1.435146 -0.789186
# 99996  0.023527  1.748632 -1.582710  0.690351     0.843101 -0.235069
# 99997 -0.041496  0.423785  0.307763  0.817859    -0.803813 -0.592984
# 99998 -0.001386 -0.423140  0.307763 -0.369978     0.546690 -0.166444
# 99999  0.019287 -0.423140  0.307763 -0.846455     0.769937 -0.046143
#
#           plate       MJD  fiber_ID  target
# 0      0.228633  0.423203 -1.021342       0
# 1      1.797924  1.420729 -0.081883       0
# 2     -0.190025  0.001854 -0.551612       0
# 3      1.358942  1.354927  1.195196       0
# 4      0.333297  0.330860  1.441070       0
# ...         ...       ...       ...     ...
# 99995  1.435155  1.194571 -0.041515       0
# 99996  0.843071  0.743915  1.529144       0
# 99997 -0.803786 -0.582617 -1.377309       0
# 99998  0.546691  0.430945  0.075917       0
# 99999  0.769908  0.837917  1.474098       0
#
# [100000 rows x 17 columns]

# %% [markdown]
# - 표준화를 진행한 std_s_df에서 target을 제외한 feature들에 대해 이상치를 제거합니다.

# %%
for feature in std_s_df.iloc[:, :-1].columns:
    print(f'{feature}: {std_s_df[~std_s_df[feature].between(-1.96, 1.96)].shape[0]}건')
# Out:
# obj_ID: 225건
# alpha: 0건
# delta: 1926건
# u: 1건
# g: 1건
# r: 3555건
# i: 3270건
# z: 1건
# run_ID: 225건
# cam_col: 0건
# field_ID: 5426건
# spec_obj_ID: 2597건
# redshift: 6256건
# plate: 2597건
# MJD: 2446건
# fiber_ID: 1162건

# %%
for feature in std_s_df.iloc[:, :-1].columns:
    std_s_df.drop(std_s_df[~std_s_df[feature].between(-1.96, 1.96)].index, axis=0, inplace=True)

# %%
for feature in std_s_df.iloc[:, :-1].columns:
    print(f'{feature}: {std_s_df[~std_s_df[feature].between(-1.96, 1.96)].shape[0]}건')
# Out:
# obj_ID: 0건
# alpha: 0건
# delta: 0건
# u: 0건
# g: 0건
# r: 0건
# i: 0건
# z: 0건
# run_ID: 0건
# cam_col: 0건
# field_ID: 0건
# spec_obj_ID: 0건
# redshift: 0건
# plate: 0건
# MJD: 0건
# fiber_ID: 0건

# %% [markdown]
# - 이상치를 제거한 후 히스토그램으로 분포를 확인해봅니다.

# %%
std_s_df.hist(figsize=(15, 15))
# Out:
# array([[<Axes: title={'center': 'obj_ID'}>,
#         <Axes: title={'center': 'alpha'}>,
#         <Axes: title={'center': 'delta'}>, <Axes: title={'center': 'u'}>],
#        [<Axes: title={'center': 'g'}>, <Axes: title={'center': 'r'}>,
#         <Axes: title={'center': 'i'}>, <Axes: title={'center': 'z'}>],
#        [<Axes: title={'center': 'run_ID'}>,
#         <Axes: title={'center': 'cam_col'}>,
#         <Axes: title={'center': 'field_ID'}>,
#         <Axes: title={'center': 'spec_obj_ID'}>],
#        [<Axes: title={'center': 'redshift'}>,
#         <Axes: title={'center': 'plate'}>,
#         <Axes: title={'center': 'MJD'}>,
#         <Axes: title={'center': 'fiber_ID'}>],
#        [<Axes: title={'center': 'target'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# - 고유한 ID값을 나타내는 feature들(obj_ID, run_ID, field_ID, spec_obj_ID, fiber_ID)은 훈련에 불필요하다고 판단하여 삭제하기로 합니다.

# %%
std_s_df.drop(labels=['obj_ID', 'run_ID', 'field_ID', 'spec_obj_ID', 'fiber_ID'], axis=1, inplace=True)
std_s_df
# Out:
#           alpha     delta         u         g         r         i         z  \
# 0     -0.434604  0.425529  0.059755  0.054926  0.403962  0.046007  0.003937
# 1     -0.339921  0.363402  0.088045  0.072456  1.584406  1.185097  0.092835
# 2     -0.367251  0.582713  0.103327  0.067165  0.519745  0.150019  0.008808
# 3      1.669523 -1.249105  0.004921  0.102210  1.059904  0.807610  0.018321
# 4      1.737310 -0.150242 -0.080055 -0.092948 -1.697421 -1.767887 -0.098468
# ...         ...       ...       ...       ...       ...       ...       ...
# 99994  1.446791 -1.263329 -0.031956 -0.022524 -0.163851  0.035415  0.012263
# 99996 -1.535053 -0.220744  0.022371  0.058422  0.433626  0.382696  0.023527
# 99997  0.486606 -0.429360 -0.025538 -0.039730 -0.777184 -0.793290 -0.041496
# 99998  0.358952  1.146631  0.106075  0.034840  0.144547 -0.007005 -0.001386
# 99999  0.199654  1.289381  0.020184  0.039876  0.515103  0.526050  0.019287
#
#         cam_col  redshift     plate       MJD  target
# 0     -0.952553  0.079557  0.228633  0.423203       0
# 1      0.937920  0.277096  1.797924  1.420729       0
# 2     -0.952553  0.092423 -0.190025  0.001854       0
# 3     -0.322395  0.486770  1.358942  1.354927       0
# 4     -0.322395 -0.630267  0.333297  0.330860       0
# ...         ...       ...       ...       ...     ...
# 99994 -0.952553 -0.549408 -1.392821 -1.299242       0
# 99996 -1.582710 -0.235069  0.843071  0.743915       0
# 99997  0.307763 -0.592984 -0.803786 -0.582617       0
# 99998  0.307763 -0.166444  0.546691  0.430945       0
# 99999  0.307763 -0.046143  0.769908  0.837917       0
#
# [78209 rows x 12 columns]

# %%
std_s_df.hist(figsize=(15, 15))
# Out:
# array([[<Axes: title={'center': 'alpha'}>,
#         <Axes: title={'center': 'delta'}>, <Axes: title={'center': 'u'}>],
#        [<Axes: title={'center': 'g'}>, <Axes: title={'center': 'r'}>,
#         <Axes: title={'center': 'i'}>],
#        [<Axes: title={'center': 'z'}>,
#         <Axes: title={'center': 'cam_col'}>,
#         <Axes: title={'center': 'redshift'}>],
#        [<Axes: title={'center': 'plate'}>,
#         <Axes: title={'center': 'MJD'}>,
#         <Axes: title={'center': 'target'}>]], dtype=object)

# %% [markdown]
# - target 데이터의 비중을 확인해봅니다.

# %%
std_s_df['target'].value_counts()
# Out:
# target
# 0    50116
# 2    17460
# 1    10633
# Name: count, dtype: int64

# %% [markdown]
# - 분포 비중이 맞지 않으므로 SMOTE를 통해 oversampling을 진행하기로 하고, 먼저 train_test_split()을 통해 훈련 및 테스트 데이터를 분리합니다.

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

features, targets = std_s_df.iloc[:, :-1], std_s_df.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)
smote = SMOTE()
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

# %%
y_train_over.value_counts()
# Out:
# target
# 0    40093
# 2    40093
# 1    40093
# Name: count, dtype: int64

# %% [markdown]
# ---
# #### 3. 모델 훈련, 예측 및 평가
# - DTC
# - SVC
# - KNN
# - Ensemble(Hard/soft Voting[DTC, SVC, KNN], Bagging[RFC], Boosting[AdaBoost, GBM, XGB, LightGBM])
# - 각각 GridSearchCV를 통해 최적의 하이퍼 파라미터 탐색을 동시에 진행합니다.

# %% [markdown]
# ##### 1) DTC(Decision Tree Classifier) 분류 모델

# %% [markdown]
# - 먼저 GridSearchCV를 확인하기 전, 하이퍼 파라미터 조정 없이 DTC를 통해 훈련 및 예측을 수행한 후 feature별 중요도를 시각화해봅니다.

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()

dtc.fit(X_train_over, y_train_over)
# Out:
# DecisionTreeClassifier()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x=dtc.feature_importances_, y=features.columns)
plt.show()

# %% [markdown]
# - 중요도가 가장 높은 상위 2개 feature(redshift, u)를 산점도로 시각화해봅니다.

# %%
plt.scatter(features.iloc[:, -3], features.iloc[:, 2], c=targets)
plt.show()

# %% [markdown]
# - 결정 경계를 시각화해봅니다.

# %%
import numpy as np

# Classifier의 Decision Boundary를 시각화 하는 함수
def visualize_boundary(model, X, y):
    fig,ax = plt.subplots()
    
    # 학습 데이타 scatter plot으로 나타내기
    ax.scatter(X.iloc[:, 0], X.iloc[:, 1], c=y, s=25, cmap='rainbow', edgecolor='k',
               clim=(y.min(), y.max()), zorder=3)
    ax.axis('tight')
    ax.axis('off')
    xlim_start , xlim_end = ax.get_xlim()
    ylim_start , ylim_end = ax.get_ylim()
    
    # 호출 파라미터로 들어온 training 데이타로 model 학습 . 
    model.fit(X, y)
    # meshgrid 형태인 모든 좌표값으로 예측 수행. 
    xx, yy = np.meshgrid(np.linspace(xlim_start,xlim_end, num=200),np.linspace(ylim_start,ylim_end, num=200))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
    
    # contourf() 를 이용하여 class boundary 를 visualization 수행. 
    n_classes = len(np.unique(y))
    contours = ax.contourf(xx, yy, Z, alpha=0.3,
                           levels=np.arange(n_classes + 1) - 0.5,
                           cmap='rainbow',
                           zorder=1)

# %%
from copy import deepcopy

features_dtc = deepcopy(dtc)
features_2_8 = features.iloc[:, [2, 8]]
visualize_boundary(features_dtc, features_2_8, targets)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# - 과적합이 발생했다고 판단하여, GridSearchCV를 통해 최적의 하이퍼 파라미터 값을 찾아 조정하고자 합니다.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

dtc = DecisionTreeClassifier()

parameters = {
    'max_depth': [5, 6, 7],
    'min_samples_split': [7, 8, 9]
}

g_dtc = GridSearchCV(dtc, param_grid=parameters, cv=5, refit=True, return_train_score=True, n_jobs=-1)

g_dtc.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [5, 6, 7],
#                          'min_samples_split': [7, 8, 9]},
#              return_train_score=True)

# %%
dtc_result_df = pd.DataFrame(g_dtc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(dtc_result_df)
# Out:
#                                      params  mean_test_score  rank_test_score
# 0  {'max_depth': 5, 'min_samples_split': 7}         0.955412                7
# 1  {'max_depth': 5, 'min_samples_split': 8}         0.955412                7
# 2  {'max_depth': 5, 'min_samples_split': 9}         0.955412                7
# 3  {'max_depth': 6, 'min_samples_split': 7}         0.960633                5
# 4  {'max_depth': 6, 'min_samples_split': 8}         0.960642                4
# 5  {'max_depth': 6, 'min_samples_split': 9}         0.960633                5
# 6  {'max_depth': 7, 'min_samples_split': 7}         0.963335                1
# 7  {'max_depth': 7, 'min_samples_split': 8}         0.963319                2
# 8  {'max_depth': 7, 'min_samples_split': 9}         0.963302                3

# %%
dtc = g_dtc.best_estimator_

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x=dtc.feature_importances_, y=features.columns)
plt.show()

# %%
plt.scatter(features.iloc[:, -3], features.iloc[:, 2], c=targets)
plt.show()

# %%
from copy import deepcopy

features_dtc = deepcopy(dtc)
features_2_8 = features.iloc[:, [2, 8]]
visualize_boundary(features_dtc, features_2_8, targets)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# - 📌이전보다 과적합이 많이 줄어들었음을 확인할 수 있습니다.

# %% [markdown]
# - 오차 행렬을 시각화해봅니다.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction, average='macro')
    recall = recall_score(y_test , prediction, average='macro')
    f1 = f1_score(y_test, prediction, average='macro')
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}'.format(accuracy, precision, recall, f1))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
dtc_prediction = dtc.predict(X_test)

# %%
get_evaluation(y_test, dtc_prediction, dtc, X_test)
# Out:
# 오차 행렬
# [[9523  460   40]
#  [ 175 1952    0]
#  [   2    0 3490]]
# 정확도: 0.9567, 정밀도: 0.9266, 재현율: 0.9558, F1: 0.9399
# ################################################################################

# %% [markdown]
# ##### 2) SVC(Support Vector machine Classifier) 분류 모델
# - 앞서 StandardScaler을 통해 스케일링을 진행하였으므로, 따로 파이프라인을 구축할 필요는 없다고 판단됩니다.
#
# - 다만, 데이터의 수가 많아 LinearSVC를 통해 linear kernel로 학습시킨 후 오차행렬을 구해봅니다.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC

l_svc_parameters = {
    'C': [0.001, 0.01, 0.1]
}

l_svc = LinearSVC(verbose=True)

g_l_svc = GridSearchCV(l_svc, param_grid=l_svc_parameters, cv=3, refit=True, return_train_score=True, n_jobs=-1)
g_l_svc.fit(X_train_over, y_train_over)
# Out:
# [LibLinear]
# GridSearchCV(cv=3, estimator=LinearSVC(verbose=True), n_jobs=-1,
#              param_grid={'C': [0.001, 0.01, 0.1]}, return_train_score=True)

# %%
l_svc_result_df = pd.DataFrame(g_l_svc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(l_svc_result_df)
# Out:
#          params  mean_test_score  rank_test_score
# 0  {'C': 0.001}         0.889274                3
# 1   {'C': 0.01}         0.917209                2
# 2    {'C': 0.1}         0.935018                1

# %%
l_svc2_parameters = {
    'C': [1, 10, 100]
}

l_svc2 = LinearSVC(verbose=True)

g_l_svc2 = GridSearchCV(l_svc2, param_grid=l_svc2_parameters, cv=3, refit=True, return_train_score=True, n_jobs=-1)
g_l_svc2.fit(X_train_over, y_train_over)
# Out:
# [LibLinear]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# GridSearchCV(cv=3, estimator=LinearSVC(verbose=True), n_jobs=-1,
#              param_grid={'C': [1, 10, 100]}, return_train_score=True)

# %%
l_svc2_result_df = pd.DataFrame(g_l_svc2.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(l_svc2_result_df)
# Out:
#        params  mean_test_score  rank_test_score
# 0    {'C': 1}         0.941153                2
# 1   {'C': 10}         0.943465                1
# 2  {'C': 100}         0.926438                3

# %% [markdown]
# - C=10 일 때의 평균 test_score가 가장 높음을 확인할 수 있습니다.

# %%
svc = g_l_svc2.best_estimator_
svc_prediction = svc.predict(X_test)

# %% [markdown]
# - 오차 행렬을 시각화해봅니다.

# %%
get_evaluation(y_test, svc_prediction, svc, X_test)
# Out:
# 오차 행렬
# [[8852 1031  140]
#  [ 150 1977    0]
#  [  37    0 3455]]
# 정확도: 0.9132, 정밀도: 0.8659, 재현율: 0.9340, F1: 0.8913
# ################################################################################

# %% [markdown]
# ##### 3) KNN(K-Nearest Neighbors) 분류 모델

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()

knn_parameters = {
    'n_neighbors': [3, 5, 7]
}

g_knn = GridSearchCV(knn, param_grid=knn_parameters, cv=5, refit=True, return_train_score=True, n_jobs=-1)
g_knn.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': [3, 5, 7]}, return_train_score=True)

# %%
knn_result_df = pd.DataFrame(g_knn.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(knn_result_df)
# Out:
#                params  mean_test_score  rank_test_score
# 0  {'n_neighbors': 3}         0.962296                1
# 1  {'n_neighbors': 5}         0.955894                2
# 2  {'n_neighbors': 7}         0.950557                3

# %% [markdown]
# - n_neighbors=3 일 때 평균 test_score가 가장 높았음을 확인할 수 있습니다.

# %%
knn = g_knn.best_estimator_
knn_prediction = knn.predict(X_test)

# %% [markdown]
# - 오차 행렬을 시각화해봅니다.

# %%
get_evaluation(y_test, knn_prediction, knn, X_test)
# Out:
# 오차 행렬
# [[9270  387  366]
#  [ 260 1850   17]
#  [ 208    9 3275]]
# 정확도: 0.9203, 정밀도: 0.8903, 재현율: 0.9108, F1: 0.9001
# ################################################################################

# %% [markdown]
# ##### 4) Ensemble - RandomForestClassifier(Bagging)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

rfc_parameters = {
    'max_depth': [10, 11, 12],
    'min_samples_split': [10, 11, 12]
}

rfc = RandomForestClassifier(n_estimators=50)

g_rfc = GridSearchCV(rfc, param_grid=rfc_parameters, cv=5, refit=True, return_train_score=True, n_jobs=-1)

g_rfc.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(n_estimators=50), n_jobs=-1,
#              param_grid={'max_depth': [10, 11, 12],
#                          'min_samples_split': [10, 11, 12]},
#              return_train_score=True)

# %%
rfc_result_df = pd.DataFrame(g_rfc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(rfc_result_df)
# Out:
#                                        params  mean_test_score  \
# 0  {'max_depth': 10, 'min_samples_split': 10}         0.971624
# 1  {'max_depth': 10, 'min_samples_split': 11}         0.971408
# 2  {'max_depth': 10, 'min_samples_split': 12}         0.971508
# 3  {'max_depth': 11, 'min_samples_split': 10}         0.972971
# 4  {'max_depth': 11, 'min_samples_split': 11}         0.972921
# 5  {'max_depth': 11, 'min_samples_split': 12}         0.973054
# 6  {'max_depth': 12, 'min_samples_split': 10}         0.974326
# 7  {'max_depth': 12, 'min_samples_split': 11}         0.974077
# 8  {'max_depth': 12, 'min_samples_split': 12}         0.973877
#
#    rank_test_score
# 0                7
# 1                9
# 2                8
# 3                5
# 4                6
# 5                4
# 6                1
# 7                2
# 8                3

# %%
rfc = g_rfc.best_estimator_
rfc_prediction = rfc.predict(X_test)

# %% [markdown]
# - 오차 행렬을 시각화해봅니다.

# %%
get_evaluation(y_test, rfc_prediction, rfc, X_test)
# Out:
# 오차 행렬
# [[9714  243   66]
#  [ 162 1965    0]
#  [   0    0 3492]]
# 정확도: 0.9699, 정밀도: 0.9517, 재현율: 0.9643, F1: 0.9578
# ################################################################################

# %% [markdown]
# ##### 5) Ensemble - VotingClassifier(Voting)
# - (1) Hard Voting

# %%
from sklearn.ensemble import VotingClassifier

hard_vc = VotingClassifier(estimators=[
    ('dtc', dtc), ('svc', svc), ('knn', knn)
], voting='hard', n_jobs=-1)

hard_vc.fit(X_train_over, y_train_over)
# Out:
# VotingClassifier(estimators=[('dtc',
#                               DecisionTreeClassifier(max_depth=7,
#                                                      min_samples_split=7)),
#                              ('svc', LinearSVC(C=10, verbose=True)),
#                              ('knn', KNeighborsClassifier(n_neighbors=3))],
#                  n_jobs=-1)

# %%
hard_vc_prediction = hard_vc.predict(X_test)

# %% [markdown]
# - 오차 행렬을 시각화해봅니다.

# %%
get_evaluation(y_test, hard_vc_prediction, hard_vc, X_test)
# Out:
# 오차 행렬
# [[9555  365  103]
#  [ 167 1960    0]
#  [   2    0 3490]]
# 정확도: 0.9593, 정밀도: 0.9323, 재현율: 0.9581, F1: 0.9445
# ################################################################################

# %% [markdown]
# - (2) Soft Voting

# %% [markdown]
# - 앞서 사용한 LinearSVC에는 predict_proba가 없으므로, Soft Voting 시에는 CalibratedClassifierCV를 활용하여 확률을 보정합니다.

# %%
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV

svc_calibrated = LinearSVC(C=0.1)
svc_calibrated.fit(X_train_over, y_train_over)
soft_svc = CalibratedClassifierCV(svc_calibrated, method='sigmoid')
soft_svc.fit(X_train_over, y_train_over)
# Out:
# CalibratedClassifierCV(estimator=LinearSVC(C=0.1))

# %%
from sklearn.ensemble import VotingClassifier

soft_vc = VotingClassifier(estimators=[
    ('dtc', dtc), ('soft_svc', soft_svc), ('knn', knn)
], voting='soft', n_jobs=-1)

soft_vc.fit(X_train_over, y_train_over)
# Out:
# VotingClassifier(estimators=[('dtc',
#                               DecisionTreeClassifier(max_depth=7,
#                                                      min_samples_split=7)),
#                              ('soft_svc',
#                               CalibratedClassifierCV(estimator=LinearSVC(C=0.1))),
#                              ('knn', KNeighborsClassifier(n_neighbors=3))],
#                  n_jobs=-1, voting='soft')

# %%
soft_vc_prediction = soft_vc.predict(X_test)

# %% [markdown]
# - 오차 행렬을 시각화해봅니다.

# %%
get_evaluation(y_test, soft_vc_prediction, soft_vc, X_test)
# Out:
# 오차 행렬
# [[9617  293  113]
#  [ 185 1941    1]
#  [   3    0 3489]]
# 정확도: 0.9620, 정밀도: 0.9393, 재현율: 0.9571, F1: 0.9479
# ################################################################################

# %% [markdown]
# ##### 6) Ensemble - AdaBoostClassifier(Boosting)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostClassifier

ada_parameters = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

g_ada = GridSearchCV(AdaBoostClassifier(), param_grid=ada_parameters, cv=5, refit=True, return_train_score=True, n_jobs=-1)
g_ada.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 150]},
#              return_train_score=True)

# %%
ada_result_df = pd.DataFrame(g_ada.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(ada_result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.664256
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.655684
# 2   {'learning_rate': 0.3, 'n_estimators': 150}         0.643396
# 3    {'learning_rate': 0.5, 'n_estimators': 50}         0.683735
# 4   {'learning_rate': 0.5, 'n_estimators': 100}         0.629785
# 5   {'learning_rate': 0.5, 'n_estimators': 150}         0.610239
# 6    {'learning_rate': 0.7, 'n_estimators': 50}         0.675446
# 7   {'learning_rate': 0.7, 'n_estimators': 100}         0.603388
# 8   {'learning_rate': 0.7, 'n_estimators': 150}         0.571445
# 9      {'learning_rate': 1, 'n_estimators': 50}         0.553504
# 10    {'learning_rate': 1, 'n_estimators': 100}         0.538772
# 11    {'learning_rate': 1, 'n_estimators': 150}         0.511352
#
#     rank_test_score
# 0                 3
# 1                 4
# 2                 5
# 3                 1
# 4                 6
# 5                 7
# 6                 2
# 7                 8
# 8                 9
# 9                10
# 10               11
# 11               12

# %%
ada = g_ada.best_estimator_
ada_prediction = ada.predict(X_test)

# %% [markdown]
# - 오차 행렬을 시각화해봅니다.

# %%
get_evaluation(y_test, ada_prediction, ada, X_test)
# Out:
# 오차 행렬
# [[9280  682   61]
#  [2023  104    0]
#  [ 109    0 3383]]
# 정확도: 0.8162, 정밀도: 0.6426, 재현율: 0.6479, F1: 0.6376
# ################################################################################

# %% [markdown]
# ##### 7) Ensemble - GradientBoostingClassifier(Boosting)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier

gbm_parameters = {
    'n_estimators': [50, 100, 500],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

g_gbc = GridSearchCV(GradientBoostingClassifier(loss='log_loss'), param_grid=gbm_parameters, cv=5, refit=True, return_train_score=True, n_jobs=-1)
g_gbc.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 500]},
#              return_train_score=True)

# %%
gbc_result_df = pd.DataFrame(g_gbc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(gbc_result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.970003
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.971932
# 2   {'learning_rate': 0.3, 'n_estimators': 500}         0.973304
# 3    {'learning_rate': 0.5, 'n_estimators': 50}         0.971267
# 4   {'learning_rate': 0.5, 'n_estimators': 100}         0.973329
# 5   {'learning_rate': 0.5, 'n_estimators': 500}         0.974676
# 6    {'learning_rate': 0.7, 'n_estimators': 50}         0.971591
# 7   {'learning_rate': 0.7, 'n_estimators': 100}         0.972456
# 8   {'learning_rate': 0.7, 'n_estimators': 500}         0.972672
# 9      {'learning_rate': 1, 'n_estimators': 50}         0.969687
# 10    {'learning_rate': 1, 'n_estimators': 100}         0.969928
# 11    {'learning_rate': 1, 'n_estimators': 500}         0.957166
#
#     rank_test_score
# 0                 9
# 1                 6
# 2                 3
# 3                 8
# 4                 2
# 5                 1
# 6                 7
# 7                 5
# 8                 4
# 9                11
# 10               10
# 11               12

# %%
gbc = g_gbc.best_estimator_
gbc_prediction = gbc.predict(X_test)

# %% [markdown]
# - 오차 행렬을 시각화해봅니다.

# %%
get_evaluation(y_test, gbc_prediction, gbc, X_test)
# Out:
# 오차 행렬
# [[9706  267   50]
#  [ 167 1950   10]
#  [   6    0 3486]]
# 정확도: 0.9680, 정밀도: 0.9484, 재현율: 0.9611, F1: 0.9546
# ################################################################################

# %% [markdown]
# ##### 8) Ensemble - XGBClassifier(Boosting)
# - eval_set 파라미터에 전달하기 위한 검증 세트를 분리하고 진행합니다.

# %%
from sklearn.model_selection import train_test_split

X_val_train, X_val_test, y_val_train, y_val_test = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=124)
evals = [(X_val_train, y_val_train), (X_val_test, y_val_test)]

# %%
from xgboost import XGBClassifier

xgb_parameters = {
    'n_estimators': [50, 100, 500],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

xgb = XGBClassifier()

g_xgb = GridSearchCV(xgb, param_grid=xgb_parameters, cv=5, refit=True, return_train_score=True, n_jobs=-1)

g_xgb.fit(X_train_over, y_train_over, early_stopping_rounds=50, eval_set=evals)
# Out:
# [0]	validation_0-mlogloss:0.74324	validation_1-mlogloss:0.74436
# [1]	validation_0-mlogloss:0.54237	validation_1-mlogloss:0.54448
# [2]	validation_0-mlogloss:0.41040	validation_1-mlogloss:0.41349
# [3]	validation_0-mlogloss:0.32071	validation_1-mlogloss:0.32408
# [4]	validation_0-mlogloss:0.25817	validation_1-mlogloss:0.26192
# [5]	validation_0-mlogloss:0.21282	validation_1-mlogloss:0.21684
# [6]	validation_0-mlogloss:0.18029	validation_1-mlogloss:0.18462
# [7]	validation_0-mlogloss:0.15664	validation_1-mlogloss:0.16116
# C:\ProgramData\anaconda3\Lib\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [8]	validation_0-mlogloss:0.13935	validation_1-mlogloss:0.14390
# [9]	validation_0-mlogloss:0.12661	validation_1-mlogloss:0.13128
# [10]	validation_0-mlogloss:0.11712	validation_1-mlogloss:0.12209
# [11]	validation_0-mlogloss:0.11007	validation_1-mlogloss:0.11520
# [12]	validation_0-mlogloss:0.10467	validation_1-mlogloss:0.11011
# [13]	validation_0-mlogloss:0.10041	validation_1-mlogloss:0.10595
# [14]	validation_0-mlogloss:0.09698	validation_1-mlogloss:0.10273
# [15]	validation_0-mlogloss:0.09447	validation_1-mlogloss:0.10034
# [16]	validation_0-mlogloss:0.09257	validation_1-mlogloss:0.09835
# [17]	validation_0-mlogloss:0.09082	validation_1-mlogloss:0.09668
# [18]	validation_0-mlogloss:0.08900	validation_1-mlogloss:0.09496
# [19]	validation_0-mlogloss:0.08780	validation_1-mlogloss:0.09388
# [20]	validation_0-mlogloss:0.08655	validation_1-mlogloss:0.09252
# [21]	validation_0-mlogloss:0.08556	validation_1-mlogloss:0.09140
# [22]	validation_0-mlogloss:0.08416	validation_1-mlogloss:0.08989
# [23]	validation_0-mlogloss:0.08230	validation_1-mlogloss:0.08830
# [24]	validation_0-mlogloss:0.08147	validation_1-mlogloss:0.08730
# [25]	validation_0-mlogloss:0.08028	validation_1-mlogloss:0.08619
# [26]	validation_0-mlogloss:0.07918	validation_1-mlogloss:0.08535
# [27]	validation_0-mlogloss:0.07861	validation_1-mlogloss:0.08482
# [28]	validation_0-mlogloss:0.07773	validation_1-mlogloss:0.08412
# [29]	validation_0-mlogloss:0.07663	validation_1-mlogloss:0.08284
# [30]	validation_0-mlogloss:0.07552	validation_1-mlogloss:0.08178
# [31]	validation_0-mlogloss:0.07498	validation_1-mlogloss:0.08128
# [32]	validation_0-mlogloss:0.07438	validation_1-mlogloss:0.08070
# [33]	validation_0-mlogloss:0.07364	validation_1-mlogloss:0.07981
# [34]	validation_0-mlogloss:0.07300	validation_1-mlogloss:0.07907
# [35]	validation_0-mlogloss:0.07215	validation_1-mlogloss:0.07822
# [36]	validation_0-mlogloss:0.07079	validation_1-mlogloss:0.07679
# [37]	validation_0-mlogloss:0.06966	validation_1-mlogloss:0.07560
# [38]	validation_0-mlogloss:0.06874	validation_1-mlogloss:0.07463
# [39]	validation_0-mlogloss:0.06791	validation_1-mlogloss:0.07391
# [40]	validation_0-mlogloss:0.06744	validation_1-mlogloss:0.07338
# [41]	validation_0-mlogloss:0.06687	validation_1-mlogloss:0.07261
# [42]	validation_0-mlogloss:0.06611	validation_1-mlogloss:0.07164
# [43]	validation_0-mlogloss:0.06528	validation_1-mlogloss:0.07058
# [44]	validation_0-mlogloss:0.06510	validation_1-mlogloss:0.07030
# [45]	validation_0-mlogloss:0.06427	validation_1-mlogloss:0.06914
# [46]	validation_0-mlogloss:0.06371	validation_1-mlogloss:0.06863
# [47]	validation_0-mlogloss:0.06344	validation_1-mlogloss:0.06829
# [48]	validation_0-mlogloss:0.06288	validation_1-mlogloss:0.06780
# [49]	validation_0-mlogloss:0.06249	validation_1-mlogloss:0.06727
# [50]	validation_0-mlogloss:0.06191	validation_1-mlogloss:0.06673
# [51]	validation_0-mlogloss:0.06128	validation_1-mlogloss:0.06612
# [52]	validation_0-mlogloss:0.06070	validation_1-mlogloss:0.06553
# [53]	validation_0-mlogloss:0.06031	validation_1-mlogloss:0.06524
# [54]	validation_0-mlogloss:0.05982	validation_1-mlogloss:0.06475
# [55]	validation_0-mlogloss:0.05928	validation_1-mlogloss:0.06411
# [56]	validation_0-mlogloss:0.05884	validation_1-mlogloss:0.06376
# [57]	validation_0-mlogloss:0.05833	validation_1-mlogloss:0.06304
# [58]	validation_0-mlogloss:0.05810	validation_1-mlogloss:0.06283
# [59]	validation_0-mlogloss:0.05752	validation_1-mlogloss:0.06212
# [60]	validation_0-mlogloss:0.05718	validation_1-mlogloss:0.06166
# [61]	validation_0-mlogloss:0.05657	validation_1-mlogloss:0.06082
# [62]	validation_0-mlogloss:0.05625	validation_1-mlogloss:0.06042
# [63]	validation_0-mlogloss:0.05584	validation_1-mlogloss:0.06001
# [64]	validation_0-mlogloss:0.05515	validation_1-mlogloss:0.05924
# [65]	validation_0-mlogloss:0.05489	validation_1-mlogloss:0.05893
# [66]	validation_0-mlogloss:0.05440	validation_1-mlogloss:0.05848
# [67]	validation_0-mlogloss:0.05392	validation_1-mlogloss:0.05779
# [68]	validation_0-mlogloss:0.05341	validation_1-mlogloss:0.05724
# [69]	validation_0-mlogloss:0.05285	validation_1-mlogloss:0.05658
# [70]	validation_0-mlogloss:0.05231	validation_1-mlogloss:0.05589
# [71]	validation_0-mlogloss:0.05190	validation_1-mlogloss:0.05547
# [72]	validation_0-mlogloss:0.05150	validation_1-mlogloss:0.05490
# [73]	validation_0-mlogloss:0.05075	validation_1-mlogloss:0.05419
# [74]	validation_0-mlogloss:0.05046	validation_1-mlogloss:0.05372
# [75]	validation_0-mlogloss:0.04988	validation_1-mlogloss:0.05303
# [76]	validation_0-mlogloss:0.04966	validation_1-mlogloss:0.05271
# [77]	validation_0-mlogloss:0.04925	validation_1-mlogloss:0.05233
# [78]	validation_0-mlogloss:0.04887	validation_1-mlogloss:0.05191
# [79]	validation_0-mlogloss:0.04825	validation_1-mlogloss:0.05123
# [80]	validation_0-mlogloss:0.04767	validation_1-mlogloss:0.05067
# [81]	validation_0-mlogloss:0.04704	validation_1-mlogloss:0.05008
# [82]	validation_0-mlogloss:0.04635	validation_1-mlogloss:0.04940
# [83]	validation_0-mlogloss:0.04609	validation_1-mlogloss:0.04911
# [84]	validation_0-mlogloss:0.04586	validation_1-mlogloss:0.04885
# [85]	validation_0-mlogloss:0.04554	validation_1-mlogloss:0.04848
# [86]	validation_0-mlogloss:0.04520	validation_1-mlogloss:0.04802
# [87]	validation_0-mlogloss:0.04493	validation_1-mlogloss:0.04773
# [88]	validation_0-mlogloss:0.04469	validation_1-mlogloss:0.04749
# [89]	validation_0-mlogloss:0.04428	validation_1-mlogloss:0.04703
# [90]	validation_0-mlogloss:0.04388	validation_1-mlogloss:0.04664
# [91]	validation_0-mlogloss:0.04337	validation_1-mlogloss:0.04611
# [92]	validation_0-mlogloss:0.04303	validation_1-mlogloss:0.04574
# [93]	validation_0-mlogloss:0.04295	validation_1-mlogloss:0.04564
# [94]	validation_0-mlogloss:0.04268	validation_1-mlogloss:0.04535
# [95]	validation_0-mlogloss:0.04229	validation_1-mlogloss:0.04502
# [96]	validation_0-mlogloss:0.04207	validation_1-mlogloss:0.04477
# [97]	validation_0-mlogloss:0.04180	validation_1-mlogloss:0.04443
# [98]	validation_0-mlogloss:0.04164	validation_1-mlogloss:0.04419
# [99]	validation_0-mlogloss:0.04127	validation_1-mlogloss:0.04363
# [100]	validation_0-mlogloss:0.04065	validation_1-mlogloss:0.04300
# [101]	validation_0-mlogloss:0.04049	validation_1-mlogloss:0.04282
# [102]	validation_0-mlogloss:0.04003	validation_1-mlogloss:0.04226
# [103]	validation_0-mlogloss:0.03993	validation_1-mlogloss:0.04216
# [104]	validation_0-mlogloss:0.03969	validation_1-mlogloss:0.04190
# [105]	validation_0-mlogloss:0.03932	validation_1-mlogloss:0.04140
# [106]	validation_0-mlogloss:0.03887	validation_1-mlogloss:0.04092
# [107]	validation_0-mlogloss:0.03861	validation_1-mlogloss:0.04066
# [108]	validation_0-mlogloss:0.03844	validation_1-mlogloss:0.04045
# [109]	validation_0-mlogloss:0.03831	validation_1-mlogloss:0.04026
# [110]	validation_0-mlogloss:0.03797	validation_1-mlogloss:0.03985
# [111]	validation_0-mlogloss:0.03767	validation_1-mlogloss:0.03951
# [112]	validation_0-mlogloss:0.03731	validation_1-mlogloss:0.03915
# [113]	validation_0-mlogloss:0.03699	validation_1-mlogloss:0.03878
# [114]	validation_0-mlogloss:0.03692	validation_1-mlogloss:0.03867
# [115]	validation_0-mlogloss:0.03662	validation_1-mlogloss:0.03830
# [116]	validation_0-mlogloss:0.03625	validation_1-mlogloss:0.03790
# [117]	validation_0-mlogloss:0.03587	validation_1-mlogloss:0.03759
# [118]	validation_0-mlogloss:0.03569	validation_1-mlogloss:0.03738
# [119]	validation_0-mlogloss:0.03557	validation_1-mlogloss:0.03722
# [120]	validation_0-mlogloss:0.03522	validation_1-mlogloss:0.03683
# [121]	validation_0-mlogloss:0.03485	validation_1-mlogloss:0.03634
# [122]	validation_0-mlogloss:0.03442	validation_1-mlogloss:0.03583
# [123]	validation_0-mlogloss:0.03410	validation_1-mlogloss:0.03552
# [124]	validation_0-mlogloss:0.03395	validation_1-mlogloss:0.03535
# [125]	validation_0-mlogloss:0.03370	validation_1-mlogloss:0.03508
# [126]	validation_0-mlogloss:0.03344	validation_1-mlogloss:0.03484
# [127]	validation_0-mlogloss:0.03314	validation_1-mlogloss:0.03454
# [128]	validation_0-mlogloss:0.03278	validation_1-mlogloss:0.03409
# [129]	validation_0-mlogloss:0.03256	validation_1-mlogloss:0.03378
# [130]	validation_0-mlogloss:0.03236	validation_1-mlogloss:0.03347
# [131]	validation_0-mlogloss:0.03215	validation_1-mlogloss:0.03317
# [132]	validation_0-mlogloss:0.03203	validation_1-mlogloss:0.03306
# [133]	validation_0-mlogloss:0.03195	validation_1-mlogloss:0.03298
# [134]	validation_0-mlogloss:0.03184	validation_1-mlogloss:0.03284
# [135]	validation_0-mlogloss:0.03169	validation_1-mlogloss:0.03270
# [136]	validation_0-mlogloss:0.03134	validation_1-mlogloss:0.03237
# [137]	validation_0-mlogloss:0.03113	validation_1-mlogloss:0.03207
# [138]	validation_0-mlogloss:0.03102	validation_1-mlogloss:0.03196
# [139]	validation_0-mlogloss:0.03085	validation_1-mlogloss:0.03177
# [140]	validation_0-mlogloss:0.03061	validation_1-mlogloss:0.03159
# [141]	validation_0-mlogloss:0.03043	validation_1-mlogloss:0.03136
# [142]	validation_0-mlogloss:0.03016	validation_1-mlogloss:0.03103
# [143]	validation_0-mlogloss:0.02994	validation_1-mlogloss:0.03082
# [144]	validation_0-mlogloss:0.02961	validation_1-mlogloss:0.03044
# [145]	validation_0-mlogloss:0.02933	validation_1-mlogloss:0.03009
# [146]	validation_0-mlogloss:0.02905	validation_1-mlogloss:0.02979
# [147]	validation_0-mlogloss:0.02880	validation_1-mlogloss:0.02950
# [148]	validation_0-mlogloss:0.02845	validation_1-mlogloss:0.02911
# [149]	validation_0-mlogloss:0.02815	validation_1-mlogloss:0.02877
# [150]	validation_0-mlogloss:0.02797	validation_1-mlogloss:0.02858
# [151]	validation_0-mlogloss:0.02770	validation_1-mlogloss:0.02824
# [152]	validation_0-mlogloss:0.02757	validation_1-mlogloss:0.02813
# [153]	validation_0-mlogloss:0.02733	validation_1-mlogloss:0.02783
# [154]	validation_0-mlogloss:0.02699	validation_1-mlogloss:0.02742
# [155]	validation_0-mlogloss:0.02679	validation_1-mlogloss:0.02716
# [156]	validation_0-mlogloss:0.02665	validation_1-mlogloss:0.02703
# [157]	validation_0-mlogloss:0.02652	validation_1-mlogloss:0.02688
# [158]	validation_0-mlogloss:0.02635	validation_1-mlogloss:0.02660
# [159]	validation_0-mlogloss:0.02612	validation_1-mlogloss:0.02636
# [160]	validation_0-mlogloss:0.02598	validation_1-mlogloss:0.02623
# [161]	validation_0-mlogloss:0.02578	validation_1-mlogloss:0.02595
# [162]	validation_0-mlogloss:0.02561	validation_1-mlogloss:0.02581
# [163]	validation_0-mlogloss:0.02542	validation_1-mlogloss:0.02557
# [164]	validation_0-mlogloss:0.02530	validation_1-mlogloss:0.02542
# [165]	validation_0-mlogloss:0.02523	validation_1-mlogloss:0.02535
# [166]	validation_0-mlogloss:0.02506	validation_1-mlogloss:0.02515
# [167]	validation_0-mlogloss:0.02480	validation_1-mlogloss:0.02497
# [168]	validation_0-mlogloss:0.02466	validation_1-mlogloss:0.02488
# [169]	validation_0-mlogloss:0.02449	validation_1-mlogloss:0.02465
# [170]	validation_0-mlogloss:0.02423	validation_1-mlogloss:0.02441
# [171]	validation_0-mlogloss:0.02415	validation_1-mlogloss:0.02430
# [172]	validation_0-mlogloss:0.02403	validation_1-mlogloss:0.02421
# [173]	validation_0-mlogloss:0.02379	validation_1-mlogloss:0.02396
# [174]	validation_0-mlogloss:0.02355	validation_1-mlogloss:0.02373
# [175]	validation_0-mlogloss:0.02335	validation_1-mlogloss:0.02352
# [176]	validation_0-mlogloss:0.02325	validation_1-mlogloss:0.02339
# [177]	validation_0-mlogloss:0.02311	validation_1-mlogloss:0.02321
# [178]	validation_0-mlogloss:0.02296	validation_1-mlogloss:0.02301
# [179]	validation_0-mlogloss:0.02281	validation_1-mlogloss:0.02284
# [180]	validation_0-mlogloss:0.02274	validation_1-mlogloss:0.02274
# [181]	validation_0-mlogloss:0.02262	validation_1-mlogloss:0.02263
# [182]	validation_0-mlogloss:0.02245	validation_1-mlogloss:0.02252
# [183]	validation_0-mlogloss:0.02237	validation_1-mlogloss:0.02243
# [184]	validation_0-mlogloss:0.02220	validation_1-mlogloss:0.02224
# [185]	validation_0-mlogloss:0.02211	validation_1-mlogloss:0.02215
# [186]	validation_0-mlogloss:0.02206	validation_1-mlogloss:0.02210
# [187]	validation_0-mlogloss:0.02194	validation_1-mlogloss:0.02199
# [188]	validation_0-mlogloss:0.02173	validation_1-mlogloss:0.02181
# [189]	validation_0-mlogloss:0.02155	validation_1-mlogloss:0.02163
# [190]	validation_0-mlogloss:0.02144	validation_1-mlogloss:0.02154
# [191]	validation_0-mlogloss:0.02129	validation_1-mlogloss:0.02138
# [192]	validation_0-mlogloss:0.02108	validation_1-mlogloss:0.02112
# [193]	validation_0-mlogloss:0.02096	validation_1-mlogloss:0.02101
# [194]	validation_0-mlogloss:0.02075	validation_1-mlogloss:0.02082
# [195]	validation_0-mlogloss:0.02065	validation_1-mlogloss:0.02072
# [196]	validation_0-mlogloss:0.02051	validation_1-mlogloss:0.02059
# [197]	validation_0-mlogloss:0.02035	validation_1-mlogloss:0.02045
# [198]	validation_0-mlogloss:0.02015	validation_1-mlogloss:0.02023
# [199]	validation_0-mlogloss:0.01996	validation_1-mlogloss:0.02003
# [200]	validation_0-mlogloss:0.01979	validation_1-mlogloss:0.01985
# [201]	validation_0-mlogloss:0.01965	validation_1-mlogloss:0.01968
# [202]	validation_0-mlogloss:0.01947	validation_1-mlogloss:0.01946
# [203]	validation_0-mlogloss:0.01933	validation_1-mlogloss:0.01937
# [204]	validation_0-mlogloss:0.01918	validation_1-mlogloss:0.01924
# [205]	validation_0-mlogloss:0.01894	validation_1-mlogloss:0.01899
# [206]	validation_0-mlogloss:0.01877	validation_1-mlogloss:0.01877
# [207]	validation_0-mlogloss:0.01865	validation_1-mlogloss:0.01862
# [208]	validation_0-mlogloss:0.01853	validation_1-mlogloss:0.01848
# [209]	validation_0-mlogloss:0.01847	validation_1-mlogloss:0.01845
# [210]	validation_0-mlogloss:0.01843	validation_1-mlogloss:0.01840
# [211]	validation_0-mlogloss:0.01830	validation_1-mlogloss:0.01831
# [212]	validation_0-mlogloss:0.01814	validation_1-mlogloss:0.01815
# [213]	validation_0-mlogloss:0.01798	validation_1-mlogloss:0.01802
# [214]	validation_0-mlogloss:0.01780	validation_1-mlogloss:0.01786
# [215]	validation_0-mlogloss:0.01769	validation_1-mlogloss:0.01772
# [216]	validation_0-mlogloss:0.01758	validation_1-mlogloss:0.01758
# [217]	validation_0-mlogloss:0.01749	validation_1-mlogloss:0.01750
# [218]	validation_0-mlogloss:0.01737	validation_1-mlogloss:0.01738
# [219]	validation_0-mlogloss:0.01725	validation_1-mlogloss:0.01726
# [220]	validation_0-mlogloss:0.01708	validation_1-mlogloss:0.01715
# [221]	validation_0-mlogloss:0.01697	validation_1-mlogloss:0.01703
# [222]	validation_0-mlogloss:0.01685	validation_1-mlogloss:0.01689
# [223]	validation_0-mlogloss:0.01674	validation_1-mlogloss:0.01675
# [224]	validation_0-mlogloss:0.01660	validation_1-mlogloss:0.01661
# [225]	validation_0-mlogloss:0.01645	validation_1-mlogloss:0.01647
# [226]	validation_0-mlogloss:0.01630	validation_1-mlogloss:0.01632
# [227]	validation_0-mlogloss:0.01620	validation_1-mlogloss:0.01622
# [228]	validation_0-mlogloss:0.01611	validation_1-mlogloss:0.01611
# [229]	validation_0-mlogloss:0.01608	validation_1-mlogloss:0.01609
# [230]	validation_0-mlogloss:0.01596	validation_1-mlogloss:0.01597
# [231]	validation_0-mlogloss:0.01585	validation_1-mlogloss:0.01585
# [232]	validation_0-mlogloss:0.01574	validation_1-mlogloss:0.01575
# [233]	validation_0-mlogloss:0.01557	validation_1-mlogloss:0.01563
# [234]	validation_0-mlogloss:0.01546	validation_1-mlogloss:0.01550
# [235]	validation_0-mlogloss:0.01533	validation_1-mlogloss:0.01540
# [236]	validation_0-mlogloss:0.01519	validation_1-mlogloss:0.01528
# [237]	validation_0-mlogloss:0.01505	validation_1-mlogloss:0.01514
# [238]	validation_0-mlogloss:0.01497	validation_1-mlogloss:0.01505
# [239]	validation_0-mlogloss:0.01489	validation_1-mlogloss:0.01494
# [240]	validation_0-mlogloss:0.01472	validation_1-mlogloss:0.01474
# [241]	validation_0-mlogloss:0.01467	validation_1-mlogloss:0.01466
# [242]	validation_0-mlogloss:0.01460	validation_1-mlogloss:0.01459
# [243]	validation_0-mlogloss:0.01459	validation_1-mlogloss:0.01457
# [244]	validation_0-mlogloss:0.01454	validation_1-mlogloss:0.01450
# [245]	validation_0-mlogloss:0.01444	validation_1-mlogloss:0.01441
# [246]	validation_0-mlogloss:0.01425	validation_1-mlogloss:0.01425
# [247]	validation_0-mlogloss:0.01417	validation_1-mlogloss:0.01414
# [248]	validation_0-mlogloss:0.01412	validation_1-mlogloss:0.01407
# [249]	validation_0-mlogloss:0.01400	validation_1-mlogloss:0.01395
# [250]	validation_0-mlogloss:0.01393	validation_1-mlogloss:0.01388
# [251]	validation_0-mlogloss:0.01376	validation_1-mlogloss:0.01370
# [252]	validation_0-mlogloss:0.01363	validation_1-mlogloss:0.01355
# [253]	validation_0-mlogloss:0.01350	validation_1-mlogloss:0.01342
# [254]	validation_0-mlogloss:0.01335	validation_1-mlogloss:0.01330
# [255]	validation_0-mlogloss:0.01327	validation_1-mlogloss:0.01321
# [256]	validation_0-mlogloss:0.01319	validation_1-mlogloss:0.01313
# [257]	validation_0-mlogloss:0.01309	validation_1-mlogloss:0.01305
# [258]	validation_0-mlogloss:0.01299	validation_1-mlogloss:0.01293
# [259]	validation_0-mlogloss:0.01288	validation_1-mlogloss:0.01284
# [260]	validation_0-mlogloss:0.01283	validation_1-mlogloss:0.01278
# [261]	validation_0-mlogloss:0.01276	validation_1-mlogloss:0.01272
# [262]	validation_0-mlogloss:0.01266	validation_1-mlogloss:0.01262
# [263]	validation_0-mlogloss:0.01259	validation_1-mlogloss:0.01256
# [264]	validation_0-mlogloss:0.01252	validation_1-mlogloss:0.01248
# [265]	validation_0-mlogloss:0.01243	validation_1-mlogloss:0.01239
# [266]	validation_0-mlogloss:0.01235	validation_1-mlogloss:0.01232
# [267]	validation_0-mlogloss:0.01228	validation_1-mlogloss:0.01225
# [268]	validation_0-mlogloss:0.01226	validation_1-mlogloss:0.01221
# [269]	validation_0-mlogloss:0.01216	validation_1-mlogloss:0.01212
# [270]	validation_0-mlogloss:0.01209	validation_1-mlogloss:0.01201
# [271]	validation_0-mlogloss:0.01196	validation_1-mlogloss:0.01191
# [272]	validation_0-mlogloss:0.01185	validation_1-mlogloss:0.01180
# [273]	validation_0-mlogloss:0.01177	validation_1-mlogloss:0.01173
# [274]	validation_0-mlogloss:0.01171	validation_1-mlogloss:0.01167
# [275]	validation_0-mlogloss:0.01159	validation_1-mlogloss:0.01160
# [276]	validation_0-mlogloss:0.01151	validation_1-mlogloss:0.01151
# [277]	validation_0-mlogloss:0.01143	validation_1-mlogloss:0.01140
# [278]	validation_0-mlogloss:0.01133	validation_1-mlogloss:0.01132
# [279]	validation_0-mlogloss:0.01125	validation_1-mlogloss:0.01122
# [280]	validation_0-mlogloss:0.01121	validation_1-mlogloss:0.01117
# [281]	validation_0-mlogloss:0.01113	validation_1-mlogloss:0.01110
# [282]	validation_0-mlogloss:0.01109	validation_1-mlogloss:0.01105
# [283]	validation_0-mlogloss:0.01100	validation_1-mlogloss:0.01098
# [284]	validation_0-mlogloss:0.01088	validation_1-mlogloss:0.01085
# [285]	validation_0-mlogloss:0.01079	validation_1-mlogloss:0.01079
# [286]	validation_0-mlogloss:0.01075	validation_1-mlogloss:0.01075
# [287]	validation_0-mlogloss:0.01067	validation_1-mlogloss:0.01066
# [288]	validation_0-mlogloss:0.01058	validation_1-mlogloss:0.01059
# [289]	validation_0-mlogloss:0.01054	validation_1-mlogloss:0.01056
# [290]	validation_0-mlogloss:0.01049	validation_1-mlogloss:0.01050
# [291]	validation_0-mlogloss:0.01045	validation_1-mlogloss:0.01046
# [292]	validation_0-mlogloss:0.01038	validation_1-mlogloss:0.01039
# [293]	validation_0-mlogloss:0.01035	validation_1-mlogloss:0.01035
# [294]	validation_0-mlogloss:0.01031	validation_1-mlogloss:0.01030
# [295]	validation_0-mlogloss:0.01026	validation_1-mlogloss:0.01026
# [296]	validation_0-mlogloss:0.01019	validation_1-mlogloss:0.01015
# [297]	validation_0-mlogloss:0.01010	validation_1-mlogloss:0.01009
# [298]	validation_0-mlogloss:0.01000	validation_1-mlogloss:0.01000
# [299]	validation_0-mlogloss:0.00991	validation_1-mlogloss:0.00990
# [300]	validation_0-mlogloss:0.00984	validation_1-mlogloss:0.00983
# [301]	validation_0-mlogloss:0.00978	validation_1-mlogloss:0.00977
# [302]	validation_0-mlogloss:0.00973	validation_1-mlogloss:0.00973
# [303]	validation_0-mlogloss:0.00971	validation_1-mlogloss:0.00972
# [304]	validation_0-mlogloss:0.00966	validation_1-mlogloss:0.00966
# [305]	validation_0-mlogloss:0.00960	validation_1-mlogloss:0.00959
# [306]	validation_0-mlogloss:0.00953	validation_1-mlogloss:0.00951
# [307]	validation_0-mlogloss:0.00950	validation_1-mlogloss:0.00947
# [308]	validation_0-mlogloss:0.00944	validation_1-mlogloss:0.00941
# [309]	validation_0-mlogloss:0.00938	validation_1-mlogloss:0.00935
# [310]	validation_0-mlogloss:0.00932	validation_1-mlogloss:0.00929
# [311]	validation_0-mlogloss:0.00929	validation_1-mlogloss:0.00925
# [312]	validation_0-mlogloss:0.00927	validation_1-mlogloss:0.00923
# [313]	validation_0-mlogloss:0.00924	validation_1-mlogloss:0.00920
# [314]	validation_0-mlogloss:0.00918	validation_1-mlogloss:0.00913
# [315]	validation_0-mlogloss:0.00914	validation_1-mlogloss:0.00909
# [316]	validation_0-mlogloss:0.00913	validation_1-mlogloss:0.00908
# [317]	validation_0-mlogloss:0.00907	validation_1-mlogloss:0.00903
# [318]	validation_0-mlogloss:0.00904	validation_1-mlogloss:0.00900
# [319]	validation_0-mlogloss:0.00903	validation_1-mlogloss:0.00898
# [320]	validation_0-mlogloss:0.00896	validation_1-mlogloss:0.00891
# [321]	validation_0-mlogloss:0.00887	validation_1-mlogloss:0.00886
# [322]	validation_0-mlogloss:0.00883	validation_1-mlogloss:0.00881
# [323]	validation_0-mlogloss:0.00879	validation_1-mlogloss:0.00875
# [324]	validation_0-mlogloss:0.00871	validation_1-mlogloss:0.00868
# [325]	validation_0-mlogloss:0.00866	validation_1-mlogloss:0.00864
# [326]	validation_0-mlogloss:0.00858	validation_1-mlogloss:0.00857
# [327]	validation_0-mlogloss:0.00853	validation_1-mlogloss:0.00852
# [328]	validation_0-mlogloss:0.00850	validation_1-mlogloss:0.00849
# [329]	validation_0-mlogloss:0.00842	validation_1-mlogloss:0.00840
# [330]	validation_0-mlogloss:0.00837	validation_1-mlogloss:0.00835
# [331]	validation_0-mlogloss:0.00831	validation_1-mlogloss:0.00829
# [332]	validation_0-mlogloss:0.00824	validation_1-mlogloss:0.00824
# [333]	validation_0-mlogloss:0.00818	validation_1-mlogloss:0.00817
# [334]	validation_0-mlogloss:0.00816	validation_1-mlogloss:0.00815
# [335]	validation_0-mlogloss:0.00809	validation_1-mlogloss:0.00807
# [336]	validation_0-mlogloss:0.00804	validation_1-mlogloss:0.00802
# [337]	validation_0-mlogloss:0.00797	validation_1-mlogloss:0.00795
# [338]	validation_0-mlogloss:0.00792	validation_1-mlogloss:0.00790
# [339]	validation_0-mlogloss:0.00788	validation_1-mlogloss:0.00784
# [340]	validation_0-mlogloss:0.00784	validation_1-mlogloss:0.00780
# [341]	validation_0-mlogloss:0.00781	validation_1-mlogloss:0.00779
# [342]	validation_0-mlogloss:0.00778	validation_1-mlogloss:0.00777
# [343]	validation_0-mlogloss:0.00774	validation_1-mlogloss:0.00773
# [344]	validation_0-mlogloss:0.00770	validation_1-mlogloss:0.00770
# [345]	validation_0-mlogloss:0.00766	validation_1-mlogloss:0.00765
# [346]	validation_0-mlogloss:0.00762	validation_1-mlogloss:0.00762
# [347]	validation_0-mlogloss:0.00756	validation_1-mlogloss:0.00756
# [348]	validation_0-mlogloss:0.00752	validation_1-mlogloss:0.00753
# [349]	validation_0-mlogloss:0.00748	validation_1-mlogloss:0.00748
# [350]	validation_0-mlogloss:0.00744	validation_1-mlogloss:0.00743
# [351]	validation_0-mlogloss:0.00738	validation_1-mlogloss:0.00739
# [352]	validation_0-mlogloss:0.00734	validation_1-mlogloss:0.00736
# [353]	validation_0-mlogloss:0.00730	validation_1-mlogloss:0.00731
# [354]	validation_0-mlogloss:0.00727	validation_1-mlogloss:0.00728
# [355]	validation_0-mlogloss:0.00726	validation_1-mlogloss:0.00727
# [356]	validation_0-mlogloss:0.00722	validation_1-mlogloss:0.00722
# [357]	validation_0-mlogloss:0.00716	validation_1-mlogloss:0.00716
# [358]	validation_0-mlogloss:0.00712	validation_1-mlogloss:0.00713
# [359]	validation_0-mlogloss:0.00709	validation_1-mlogloss:0.00709
# [360]	validation_0-mlogloss:0.00708	validation_1-mlogloss:0.00709
# [361]	validation_0-mlogloss:0.00703	validation_1-mlogloss:0.00704
# [362]	validation_0-mlogloss:0.00698	validation_1-mlogloss:0.00699
# [363]	validation_0-mlogloss:0.00694	validation_1-mlogloss:0.00696
# [364]	validation_0-mlogloss:0.00688	validation_1-mlogloss:0.00689
# [365]	validation_0-mlogloss:0.00684	validation_1-mlogloss:0.00686
# [366]	validation_0-mlogloss:0.00678	validation_1-mlogloss:0.00681
# [367]	validation_0-mlogloss:0.00676	validation_1-mlogloss:0.00679
# [368]	validation_0-mlogloss:0.00672	validation_1-mlogloss:0.00673
# [369]	validation_0-mlogloss:0.00669	validation_1-mlogloss:0.00672
# [370]	validation_0-mlogloss:0.00666	validation_1-mlogloss:0.00668
# [371]	validation_0-mlogloss:0.00662	validation_1-mlogloss:0.00663
# [372]	validation_0-mlogloss:0.00659	validation_1-mlogloss:0.00661
# [373]	validation_0-mlogloss:0.00656	validation_1-mlogloss:0.00656
# [374]	validation_0-mlogloss:0.00649	validation_1-mlogloss:0.00649
# [375]	validation_0-mlogloss:0.00644	validation_1-mlogloss:0.00647
# [376]	validation_0-mlogloss:0.00640	validation_1-mlogloss:0.00641
# [377]	validation_0-mlogloss:0.00636	validation_1-mlogloss:0.00638
# [378]	validation_0-mlogloss:0.00633	validation_1-mlogloss:0.00636
# [379]	validation_0-mlogloss:0.00629	validation_1-mlogloss:0.00632
# [380]	validation_0-mlogloss:0.00626	validation_1-mlogloss:0.00630
# [381]	validation_0-mlogloss:0.00624	validation_1-mlogloss:0.00628
# [382]	validation_0-mlogloss:0.00623	validation_1-mlogloss:0.00628
# [383]	validation_0-mlogloss:0.00619	validation_1-mlogloss:0.00625
# [384]	validation_0-mlogloss:0.00618	validation_1-mlogloss:0.00623
# [385]	validation_0-mlogloss:0.00615	validation_1-mlogloss:0.00619
# [386]	validation_0-mlogloss:0.00613	validation_1-mlogloss:0.00616
# [387]	validation_0-mlogloss:0.00609	validation_1-mlogloss:0.00613
# [388]	validation_0-mlogloss:0.00605	validation_1-mlogloss:0.00610
# [389]	validation_0-mlogloss:0.00603	validation_1-mlogloss:0.00606
# [390]	validation_0-mlogloss:0.00601	validation_1-mlogloss:0.00604
# [391]	validation_0-mlogloss:0.00600	validation_1-mlogloss:0.00602
# [392]	validation_0-mlogloss:0.00599	validation_1-mlogloss:0.00600
# [393]	validation_0-mlogloss:0.00596	validation_1-mlogloss:0.00597
# [394]	validation_0-mlogloss:0.00592	validation_1-mlogloss:0.00591
# [395]	validation_0-mlogloss:0.00589	validation_1-mlogloss:0.00589
# [396]	validation_0-mlogloss:0.00587	validation_1-mlogloss:0.00586
# [397]	validation_0-mlogloss:0.00584	validation_1-mlogloss:0.00584
# [398]	validation_0-mlogloss:0.00580	validation_1-mlogloss:0.00580
# [399]	validation_0-mlogloss:0.00575	validation_1-mlogloss:0.00578
# [400]	validation_0-mlogloss:0.00572	validation_1-mlogloss:0.00574
# [401]	validation_0-mlogloss:0.00567	validation_1-mlogloss:0.00571
# [402]	validation_0-mlogloss:0.00567	validation_1-mlogloss:0.00571
# [403]	validation_0-mlogloss:0.00565	validation_1-mlogloss:0.00569
# [404]	validation_0-mlogloss:0.00562	validation_1-mlogloss:0.00565
# [405]	validation_0-mlogloss:0.00561	validation_1-mlogloss:0.00564
# [406]	validation_0-mlogloss:0.00560	validation_1-mlogloss:0.00563
# [407]	validation_0-mlogloss:0.00556	validation_1-mlogloss:0.00559
# [408]	validation_0-mlogloss:0.00553	validation_1-mlogloss:0.00555
# [409]	validation_0-mlogloss:0.00550	validation_1-mlogloss:0.00551
# [410]	validation_0-mlogloss:0.00547	validation_1-mlogloss:0.00548
# [411]	validation_0-mlogloss:0.00545	validation_1-mlogloss:0.00545
# [412]	validation_0-mlogloss:0.00541	validation_1-mlogloss:0.00543
# [413]	validation_0-mlogloss:0.00539	validation_1-mlogloss:0.00541
# [414]	validation_0-mlogloss:0.00535	validation_1-mlogloss:0.00536
# [415]	validation_0-mlogloss:0.00534	validation_1-mlogloss:0.00534
# [416]	validation_0-mlogloss:0.00530	validation_1-mlogloss:0.00532
# [417]	validation_0-mlogloss:0.00529	validation_1-mlogloss:0.00529
# [418]	validation_0-mlogloss:0.00527	validation_1-mlogloss:0.00527
# [419]	validation_0-mlogloss:0.00525	validation_1-mlogloss:0.00526
# [420]	validation_0-mlogloss:0.00524	validation_1-mlogloss:0.00525
# [421]	validation_0-mlogloss:0.00521	validation_1-mlogloss:0.00522
# [422]	validation_0-mlogloss:0.00519	validation_1-mlogloss:0.00521
# [423]	validation_0-mlogloss:0.00515	validation_1-mlogloss:0.00517
# [424]	validation_0-mlogloss:0.00514	validation_1-mlogloss:0.00515
# [425]	validation_0-mlogloss:0.00511	validation_1-mlogloss:0.00513
# [426]	validation_0-mlogloss:0.00507	validation_1-mlogloss:0.00510
# [427]	validation_0-mlogloss:0.00504	validation_1-mlogloss:0.00507
# [428]	validation_0-mlogloss:0.00502	validation_1-mlogloss:0.00505
# [429]	validation_0-mlogloss:0.00497	validation_1-mlogloss:0.00502
# [430]	validation_0-mlogloss:0.00495	validation_1-mlogloss:0.00499
# [431]	validation_0-mlogloss:0.00493	validation_1-mlogloss:0.00496
# [432]	validation_0-mlogloss:0.00492	validation_1-mlogloss:0.00495
# [433]	validation_0-mlogloss:0.00489	validation_1-mlogloss:0.00493
# [434]	validation_0-mlogloss:0.00487	validation_1-mlogloss:0.00490
# [435]	validation_0-mlogloss:0.00485	validation_1-mlogloss:0.00487
# [436]	validation_0-mlogloss:0.00483	validation_1-mlogloss:0.00485
# [437]	validation_0-mlogloss:0.00481	validation_1-mlogloss:0.00483
# [438]	validation_0-mlogloss:0.00478	validation_1-mlogloss:0.00480
# [439]	validation_0-mlogloss:0.00477	validation_1-mlogloss:0.00478
# [440]	validation_0-mlogloss:0.00474	validation_1-mlogloss:0.00476
# [441]	validation_0-mlogloss:0.00473	validation_1-mlogloss:0.00474
# [442]	validation_0-mlogloss:0.00471	validation_1-mlogloss:0.00473
# [443]	validation_0-mlogloss:0.00468	validation_1-mlogloss:0.00470
# [444]	validation_0-mlogloss:0.00465	validation_1-mlogloss:0.00466
# [445]	validation_0-mlogloss:0.00464	validation_1-mlogloss:0.00464
# [446]	validation_0-mlogloss:0.00463	validation_1-mlogloss:0.00462
# [447]	validation_0-mlogloss:0.00462	validation_1-mlogloss:0.00461
# [448]	validation_0-mlogloss:0.00459	validation_1-mlogloss:0.00458
# [449]	validation_0-mlogloss:0.00455	validation_1-mlogloss:0.00455
# [450]	validation_0-mlogloss:0.00454	validation_1-mlogloss:0.00453
# [451]	validation_0-mlogloss:0.00452	validation_1-mlogloss:0.00451
# [452]	validation_0-mlogloss:0.00449	validation_1-mlogloss:0.00448
# [453]	validation_0-mlogloss:0.00447	validation_1-mlogloss:0.00446
# [454]	validation_0-mlogloss:0.00444	validation_1-mlogloss:0.00443
# [455]	validation_0-mlogloss:0.00442	validation_1-mlogloss:0.00440
# [456]	validation_0-mlogloss:0.00441	validation_1-mlogloss:0.00440
# [457]	validation_0-mlogloss:0.00437	validation_1-mlogloss:0.00436
# [458]	validation_0-mlogloss:0.00435	validation_1-mlogloss:0.00434
# [459]	validation_0-mlogloss:0.00433	validation_1-mlogloss:0.00433
# [460]	validation_0-mlogloss:0.00432	validation_1-mlogloss:0.00432
# [461]	validation_0-mlogloss:0.00430	validation_1-mlogloss:0.00430
# [462]	validation_0-mlogloss:0.00428	validation_1-mlogloss:0.00428
# [463]	validation_0-mlogloss:0.00425	validation_1-mlogloss:0.00425
# [464]	validation_0-mlogloss:0.00423	validation_1-mlogloss:0.00423
# [465]	validation_0-mlogloss:0.00421	validation_1-mlogloss:0.00420
# [466]	validation_0-mlogloss:0.00420	validation_1-mlogloss:0.00420
# [467]	validation_0-mlogloss:0.00420	validation_1-mlogloss:0.00419
# [468]	validation_0-mlogloss:0.00417	validation_1-mlogloss:0.00417
# [469]	validation_0-mlogloss:0.00416	validation_1-mlogloss:0.00416
# [470]	validation_0-mlogloss:0.00415	validation_1-mlogloss:0.00416
# [471]	validation_0-mlogloss:0.00413	validation_1-mlogloss:0.00414
# [472]	validation_0-mlogloss:0.00412	validation_1-mlogloss:0.00413
# [473]	validation_0-mlogloss:0.00410	validation_1-mlogloss:0.00411
# [474]	validation_0-mlogloss:0.00408	validation_1-mlogloss:0.00409
# [475]	validation_0-mlogloss:0.00405	validation_1-mlogloss:0.00407
# [476]	validation_0-mlogloss:0.00402	validation_1-mlogloss:0.00403
# [477]	validation_0-mlogloss:0.00401	validation_1-mlogloss:0.00402
# [478]	validation_0-mlogloss:0.00399	validation_1-mlogloss:0.00400
# [479]	validation_0-mlogloss:0.00398	validation_1-mlogloss:0.00399
# [480]	validation_0-mlogloss:0.00396	validation_1-mlogloss:0.00397
# [481]	validation_0-mlogloss:0.00394	validation_1-mlogloss:0.00396
# [482]	validation_0-mlogloss:0.00392	validation_1-mlogloss:0.00394
# [483]	validation_0-mlogloss:0.00391	validation_1-mlogloss:0.00392
# [484]	validation_0-mlogloss:0.00389	validation_1-mlogloss:0.00391
# [485]	validation_0-mlogloss:0.00387	validation_1-mlogloss:0.00389
# [486]	validation_0-mlogloss:0.00386	validation_1-mlogloss:0.00388
# [487]	validation_0-mlogloss:0.00385	validation_1-mlogloss:0.00387
# [488]	validation_0-mlogloss:0.00383	validation_1-mlogloss:0.00386
# [489]	validation_0-mlogloss:0.00382	validation_1-mlogloss:0.00384
# [490]	validation_0-mlogloss:0.00381	validation_1-mlogloss:0.00383
# [491]	validation_0-mlogloss:0.00380	validation_1-mlogloss:0.00381
# [492]	validation_0-mlogloss:0.00380	validation_1-mlogloss:0.00380
# [493]	validation_0-mlogloss:0.00379	validation_1-mlogloss:0.00379
# [494]	validation_0-mlogloss:0.00378	validation_1-mlogloss:0.00379
# [495]	validation_0-mlogloss:0.00376	validation_1-mlogloss:0.00377
# [496]	validation_0-mlogloss:0.00375	validation_1-mlogloss:0.00376
# [497]	validation_0-mlogloss:0.00375	validation_1-mlogloss:0.00376
# [498]	validation_0-mlogloss:0.00374	validation_1-mlogloss:0.00374
# [499]	validation_0-mlogloss:0.00372	validation_1-mlogloss:0.00373
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 500]},
#              return_train_score=True)

# %%
xgb_result_df = pd.DataFrame(g_xgb.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(xgb_result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.974983
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.978957
# 2   {'learning_rate': 0.3, 'n_estimators': 500}         0.984519
# 3    {'learning_rate': 0.5, 'n_estimators': 50}         0.977644
# 4   {'learning_rate': 0.5, 'n_estimators': 100}         0.981302
# 5   {'learning_rate': 0.5, 'n_estimators': 500}         0.984237
# 6    {'learning_rate': 0.7, 'n_estimators': 50}         0.979049
# 7   {'learning_rate': 0.7, 'n_estimators': 100}         0.982033
# 8   {'learning_rate': 0.7, 'n_estimators': 500}         0.984120
# 9      {'learning_rate': 1, 'n_estimators': 50}         0.979672
# 10    {'learning_rate': 1, 'n_estimators': 100}         0.982166
# 11    {'learning_rate': 1, 'n_estimators': 500}         0.983064
#
#     rank_test_score
# 0                12
# 1                10
# 2                 1
# 3                11
# 4                 7
# 5                 2
# 6                 9
# 7                 6
# 8                 3
# 9                 8
# 10                5
# 11                4

# %%
xgb = g_xgb.best_estimator_
xgb_prediction = xgb.predict(X_test)

# %% [markdown]
# - 오차 행렬을 시각화해봅니다.

# %%
get_evaluation(y_test, xgb_prediction, xgb, X_test)
# Out:
# 오차 행렬
# [[9783  198   42]
#  [ 183 1944    0]
#  [  12    0 3480]]
# 정확도: 0.9722, 정밀도: 0.9587, 재현율: 0.9622, F1: 0.9604
# ################################################################################

# %% [markdown]
# ##### 9) Ensemble - LGBMClassifier(Boosting)
# - 마찬가지로 검증 세트가 필요하므로 위에서 분리한 검증 세트를 사용합니다.

# %%
from sklearn.model_selection import GridSearchCV
from lightgbm import LGBMClassifier

lgbm_parameters = {
    'n_estimators': [50, 100, 500],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

g_lgbm = GridSearchCV(LGBMClassifier(), param_grid=lgbm_parameters, cv=5, refit=True, return_train_score=True, n_jobs=-1)
g_lgbm.fit(X_train_over, y_train_over, eval_set=evals)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004304 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2805
# [LightGBM] [Info] Number of data points in the train set: 120279, number of used features: 11
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# GridSearchCV(cv=5, estimator=LGBMClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 500]},
#              return_train_score=True)

# %%
lgbm_result_df = pd.DataFrame(g_lgbm.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(lgbm_result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.974958
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.976347
# 2   {'learning_rate': 0.3, 'n_estimators': 500}         0.936972
# 3    {'learning_rate': 0.5, 'n_estimators': 50}         0.968091
# 4   {'learning_rate': 0.5, 'n_estimators': 100}         0.962587
# 5   {'learning_rate': 0.5, 'n_estimators': 500}         0.896939
# 6    {'learning_rate': 0.7, 'n_estimators': 50}         0.964117
# 7   {'learning_rate': 0.7, 'n_estimators': 100}         0.945169
# 8   {'learning_rate': 0.7, 'n_estimators': 500}         0.905038
# 9      {'learning_rate': 1, 'n_estimators': 50}         0.954755
# 10    {'learning_rate': 1, 'n_estimators': 100}         0.846998
# 11    {'learning_rate': 1, 'n_estimators': 500}         0.732819
#
#     rank_test_score
# 0                 2
# 1                 1
# 2                 8
# 3                 3
# 4                 5
# 5                10
# 6                 4
# 7                 7
# 8                 9
# 9                 6
# 10               11
# 11               12

# %%
lgbm = g_lgbm.best_estimator_
lgbm_prediction = lgbm.predict(X_test)

# %% [markdown]
# - 오차행렬을 시각화합니다.

# %%
get_evaluation(y_test, lgbm_prediction, lgbm, X_test)
# Out:
# 오차 행렬
# [[9699  275   49]
#  [ 175 1952    0]
#  [  37    0 3455]]
# 정확도: 0.9657, 정밀도: 0.9470, 재현율: 0.9583, F1: 0.9525
# ################################################################################

# %% [markdown]
# ---
# #### 4. 정확도 및 F1 Score 비교 시각화
# - DTC, LinearSVC, KNN, RFC 의 정확도 및 F1 Score를 시각화하여 비교합니다.
# - Hard/Soft Voting의 각 정확도 및 F1 Score를 시각화하여 비교합니다.
# - AdaBoost, GBC, XGBoost, LightGBM의 각 정확도 및 F1 Score를 시각화하여 비교합니다.

# %% [markdown]
# ##### 1) DTC, LinearSVC, KNN, RFC 의 정확도 및 F1 Score

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

dtc_accuracy = accuracy_score(y_test, dtc_prediction)
svc_accuracy = accuracy_score(y_test, svc_prediction)
knn_accuracy = accuracy_score(y_test, knn_prediction)
rfc_accuracy = accuracy_score(y_test, rfc_prediction)

dtc_precision = precision_score(y_test, dtc_prediction, average='macro')
svc_precision = precision_score(y_test, svc_prediction, average='macro')
knn_precision = precision_score(y_test, knn_prediction, average='macro')
rfc_precision = precision_score(y_test, rfc_prediction, average='macro')

dtc_recall = recall_score(y_test, dtc_prediction, average='macro')
svc_recall = recall_score(y_test, svc_prediction, average='macro')
knn_recall = recall_score(y_test, knn_prediction, average='macro')
rfc_recall = recall_score(y_test, rfc_prediction, average='macro')

dtc_f1 = f1_score(y_test, dtc_prediction, average='macro')
svc_f1 = f1_score(y_test, svc_prediction, average='macro')
knn_f1 = f1_score(y_test, knn_prediction, average='macro')
rfc_f1 = f1_score(y_test, rfc_prediction, average='macro')

models = ['DTC', 'SVC', 'KNN', 'RFC']
accuracy_scores = [dtc_accuracy, svc_accuracy, knn_accuracy, rfc_accuracy]
precisions = [dtc_precision, svc_precision, knn_precision, rfc_precision]
recalls = [dtc_recall, svc_recall, knn_recall, rfc_recall]
f1_scores = [dtc_f1, svc_f1, knn_f1, rfc_f1]

# %%
data = {
    'Model': models * 4,
    'Score': accuracy_scores + precisions + recalls + f1_scores,
    'Metric': ['Accuracy'] * len(models) + ['Precision'] * len(models) + ['Recall'] * len(models) + ['F1 Score'] * len(models)
}

df = pd.DataFrame(data)

sns.barplot(data=df, x='Model', y='Score', hue='Metric')

plt.title('Evaluation Score Comparison')
plt.xlabel('Model')
plt.ylabel('Score')
plt.legend(bbox_to_anchor=(1.05, 1.0))
plt.show()

# %%
for i in range(4):
    print(f'{models[i]}의 정확도: {round(accuracy_scores[i] * 100, 4)}%, 정밀도: {round(precisions[i] * 100, 4)}%, 재현율: {round(recalls[i] * 100, 4)}%, F1 Score: {round(f1_scores[i] * 100, 4)}%')
# Out:
# DTC의 정확도: 95.6719%, 정밀도: 92.6569%, 재현율: 95.5755%, F1 Score: 93.9932%
# SVC의 정확도: 91.3182%, 정밀도: 86.5872%, 재현율: 93.4017%, F1 Score: 89.1264%
# KNN의 정확도: 92.0279%, 정밀도: 89.0308%, 재현율: 91.0833%, F1 Score: 90.0132%
# RFC의 정확도: 96.9889%, 정밀도: 95.1664%, 재현율: 96.4336%, F1 Score: 95.7848%

# %% [markdown]
# ##### 2) Hard/Soft Voting Classifier의 정확도 및 F1 Score

# %%
hard_accuracy = accuracy_score(y_test, hard_vc_prediction)
soft_accuracy = accuracy_score(y_test, soft_vc_prediction)

hard_precision = precision_score(y_test, hard_vc_prediction, average='macro')
soft_precision = precision_score(y_test, soft_vc_prediction, average='macro')

hard_recall = recall_score(y_test, hard_vc_prediction, average='macro')
soft_recall = recall_score(y_test, soft_vc_prediction, average='macro')

hard_f1 = f1_score(y_test, hard_vc_prediction, average='macro')
soft_f1 = f1_score(y_test, soft_vc_prediction, average='macro')

models = ['Hard Voting', 'Soft Voting']
accuracy_scores = [hard_accuracy, soft_accuracy]
precisions = [hard_precision, soft_precision]
recalls = [hard_recall, soft_recall]
f1_scores = [hard_f1, soft_f1]

# %%
data = {
    'Model': models * 4,
    'Score': accuracy_scores + precisions + recalls + f1_scores,
    'Metric': ['Accuracy'] * len(models) + ['Precision'] * len(models) + ['Recall'] * len(models) + ['F1 Score'] * len(models)
}

df = pd.DataFrame(data)

sns.barplot(data=df, x='Model', y='Score', hue='Metric')

plt.title('Evaluation Score Comparison')
plt.xlabel('Model')
plt.ylabel('Score')
plt.legend(bbox_to_anchor=(1.05, 1.0))
plt.show()

# %%
for i in range(2):
    print(f'{models[i]}의 정확도: {round(accuracy_scores[i] * 100, 4)}%, 정밀도: {round(precisions[i] * 100, 4)}%, 재현율: {round(recalls[i] * 100, 4)}%, F1 Score: {round(f1_scores[i] * 100, 4)}%')
# Out:
# Hard Voting의 정확도: 95.9276%, 정밀도: 93.2321%, 재현율: 95.8073%, F1 Score: 94.4475%
# Soft Voting의 정확도: 96.1961%, 정밀도: 93.9344%, 재현율: 95.7062%, F1 Score: 94.7905%

# %% [markdown]
# ##### 3) AdaBoost, GBC, XGBoost, LightGBM의 정확도 및 F1 Score

# %%
import matplotlib.pyplot as plt
import seaborn as sns
ada_accuracy = accuracy_score(y_test, ada_prediction)
gbc_accuracy = accuracy_score(y_test, gbc_prediction)
xgb_accuracy = accuracy_score(y_test, xgb_prediction)
lgbm_accuracy = accuracy_score(y_test, lgbm_prediction)

ada_precision = precision_score(y_test, ada_prediction, average='macro')
gbc_precision = precision_score(y_test, gbc_prediction, average='macro')
xgb_precision = precision_score(y_test, xgb_prediction, average='macro')
lgbm_precision = precision_score(y_test, lgbm_prediction, average='macro')

ada_recall = recall_score(y_test, ada_prediction, average='macro')
gbc_recall = recall_score(y_test, gbc_prediction, average='macro')
xgb_recall = recall_score(y_test, xgb_prediction, average='macro')
lgbm_recall = recall_score(y_test, lgbm_prediction, average='macro')

ada_f1 = f1_score(y_test, ada_prediction, average='macro')
gbc_f1 = f1_score(y_test, gbc_prediction, average='macro')
xgb_f1 = f1_score(y_test, xgb_prediction, average='macro')
lgbm_f1 = f1_score(y_test, lgbm_prediction, average='macro')

models = ['AdaBoost', 'GBC', 'XGBoost', 'LightGBM']
accuracy_scores = [ada_accuracy, gbc_accuracy, xgb_accuracy, lgbm_accuracy]
precisions = [ada_precision, gbc_precision, xgb_precision, lgbm_precision]
recalls = [ada_recall, gbc_recall, xgb_recall, lgbm_recall]
f1_scores = [ada_f1, gbc_f1, xgb_f1, lgbm_f1]

# %%
data = {
    'Model': models * 4,
    'Score': accuracy_scores + precisions + recalls + f1_scores,
    'Metric': ['Accuracy'] * len(models) + ['Precision'] * len(models) + ['Recall'] * len(models) + ['F1 Score'] * len(models)
}

df = pd.DataFrame(data)

sns.barplot(data=df, x='Model', y='Score', hue='Metric')

plt.title('Evaluation Score Comparison')
plt.xlabel('Model')
plt.ylabel('Score')
plt.legend(bbox_to_anchor=(1.05, 1.0))
plt.show()

# %%
for i in range(4):
    print(f'{models[i]}의 정확도: {round(accuracy_scores[i] * 100, 4)}%, 정밀도: {round(precisions[i] * 100, 4)}%, 재현율: {round(recalls[i] * 100, 4)}%, F1 Score: {round(f1_scores[i] * 100, 4)}%')
# Out:
# AdaBoost의 정확도: 81.62%, 정밀도: 64.2594%, 재현율: 64.785%, F1 Score: 63.7589%
# GBC의 정확도: 96.8035%, 정밀도: 94.8378%, 재현율: 96.1146%, F1 Score: 95.4597%
# XGBoost의 정확도: 97.219%, 정밀도: 95.8698%, 재현율: 96.2194%, F1 Score: 96.0435%
# LightGBM의 정확도: 96.5733%, 정밀도: 94.7047%, 재현율: 95.8268%, F1 Score: 95.2488%

# %% [markdown]
# ---
# ### 📌모델에 따른 평가 지표 점수
#
# <img src="./images/star_scores01.png" width="500px"><img src="./images/star_scores02.png" width="500px"><img src="./images/star_scores03.png" width="500px">
#
# - DTC의 정확도: 95.6719%, 정밀도: 92.6569%, 재현율: 95.5755%, F1 Score: 93.9932%
# - SVC의 정확도: 91.3182%, 정밀도: 86.5872%, 재현율: 93.4017%, F1 Score: 89.1264%
# - KNN의 정확도: 92.0279%, 정밀도: 89.0308%, 재현율: 91.0833%, F1 Score: 90.0132%
# - RFC의 정확도: 96.9889%, 정밀도: 95.1664%, 재현율: 96.4336%, F1 Score: 95.7848%
# - Hard Voting의 정확도: 95.9276%, 정밀도: 93.2321%, 재현율: 95.8073%, F1 Score: 94.4475%
# - Soft Voting의 정확도: 96.1961%, 정밀도: 93.9344%, 재현율: 95.7062%, F1 Score: 94.7905%
# - AdaBoost의 정확도: 81.62%, 정밀도: 64.2594%, 재현율: 64.785%, F1 Score: 63.7589%
# - GBC의 정확도: 96.8035%, 정밀도: 94.8378%, 재현율: 96.1146%, F1 Score: 95.4597%
# - **XGBoost의 정확도: 97.219%, 정밀도: 95.8698%, 재현율: 96.2194%, F1 Score: 96.0435%**
# - LightGBM의 정확도: 96.5733%, 정밀도: 94.7047%, 재현율: 95.8268%, F1 Score: 95.2488%

# %% [markdown]
# ### 🎈XGBoost(eXtra Gradient Boosting)Classifier 모델로 훈련했을 때 가장 높은 성능을 보였습니다.
# - 모든 feature가 target(종속 변수)과 매우 낮은 상관관계를 보였음에도 불구하고 매우 높은 분류 정확도를 나타냈습니다.
#
# - 다만, 과적합의 우려가 있으므로 상황에 따라 상대적으로 평가 지표 점수는 낮지만 시간 및 공간 복잡도가 낮은 LightGBM 모델이 더 권장될 수 있습니다.
